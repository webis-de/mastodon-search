# %%
from elasticsearch_dsl import connections, Index, Search
from elasticsearch_dsl.query import Range, Terms, Term
from elasticsearch_dsl.aggs import Terms as PerTerms, Cardinality
from json import loads, load
from pandas import DataFrame, NA
from pathlib import Path
from favicon import get as get_favicon
from requests import get

# %%
ELASTIC_HOST = "https://elasticsearch.srv.webis.de"
ELASTIC_PORT = 9200
ELASTIC_USER = "ajjxp"
# As a way to hide the password at least from the notebook, enter a path to a file here, which only contains the password for Elastic.
ELASTIC_PASSWORD_FILE = Path("~/.local/share/passwords/webis-elasticsearch.txt").expanduser()
INDEX = "corpus_mastodon_statuses*"

INSTANCE_DATA_PATH = Path("/mnt/ceph/storage/data-in-progress/data-teaching/theses/wstud-thesis-ernst/fedi_data/2024-01-30/05.jsonl")
INSTANCES_PATH = Path("/mnt/ceph/storage/data-in-progress/data-teaching/theses/wstud-thesis-ernst/sample/04/instances.txt")
REMOVED_INSTANCES_PATH = Path("/mnt/ceph/storage/data-in-progress/data-teaching/theses/wstud-thesis-ernst/sample/04/instances_removed_for_crawling_errors.json")

OUTPUT_PATH = Path("../data")

NUM_EXPLICIT_INSTANCES = 10
# Upper bound for the number of buckets in Elastic aggs. Set a bit higher than the number of instances crawled.
# SEARCH_MAX = 1100
SEARCH_MAX = 10000

# Limit the Elastic searches to a specific date range. Crawling started on 2023-12-21.
DATE_AFTER = "2023-12-01T00:00:00"
## Ca. "2024-01-30T12:00:00" is the time when a new version of the fediverse data was gahtered.
DATE_BEFORE = "2024-02-22T00:00:00"

# %%
# Connect to Elastic.
with ELASTIC_PASSWORD_FILE.open("r") as f:
    password = f.readline().strip("\n")
elastic = connections.create_connection(
    hosts=ELASTIC_HOST + ":" + str(ELASTIC_PORT),
    basic_auth=(ELASTIC_USER, password),
    timeout=300
)

# %%
# Prepare the date query
date_query = Range(crawled_at={"gte": DATE_AFTER, "lte": DATE_BEFORE, "format" : "date_hour_minute_second"})
date_query.to_dict()

# %%
base_search: Search = Index(INDEX)\
    .search()\
    .filter(date_query)
base_search.count()
# Out:
# 733422562

# %%
crawled_instances_count_search: Search = base_search.params(size=0)
crawled_instances_count_search.aggs\
    .metric(
        "instances", 
        Cardinality(field="crawled_from_instance.keyword")
    )
crawled_instances_count = crawled_instances_count_search.execute()\
    .aggs.instances.value
crawled_instances_count
# Out:
# 1015

# %%
crawled_counts_search: Search = base_search.params(size=0)
crawled_counts_search.aggs\
    .bucket(
        "instances",
        PerTerms(field="crawled_from_instance.keyword", size=crawled_instances_count)
    )
    
crawled_counts_buckets = crawled_counts_search.execute().aggs.instances.buckets
crawled_counts = {
    bucket.key: bucket.doc_count
    for bucket in crawled_counts_buckets
}
crawled_counts
# Out:
# {'mastodon.social': 15668157,
#  'mastodon.online': 9857093,
#  'mstdn.social': 9638803,
#  'ohai.social': 8754882,
#  'mas.to': 8208704,
#  'mastodon.world': 8149459,
#  'universeodon.com': 7489453,
#  'social.vivaldi.net': 7194763,
#  'techhub.social': 7121898,
#  'toot.community': 6660323,
#  'convo.casa': 6446080,
#  'mastodonapp.uk': 6324971,
#  'flipboard.social': 6310298,
#  'cupoftea.social': 5642647,
#  'masto.ai': 5383642,
#  'mastodon.sdf.org': 5241825,
#  'hachyderm.io': 5167978,
#  'fosstodon.org': 5140898,
#  'vmst.io': 5140272,
#  'infosec.exchange': 4950838,
#  'fedibird.com': 4936551,
#  'veganism.social': 4882563,
#  'c.im': 4507321,
#  'qoto.org': 4506541,
#  'mstdn.party': 4430716,
#  'mastodon.org.uk': 4395694,
#  'chaosfem.tw': 4342564,
#  'troet.cafe': 4271040,
#  'sfba.social': 4035500,
#  'mstdn.nijist.info': 3874928,
#  'mstdn.business': 3801452,
#  'chaos.social': 3751356,
#  'mindly.social': 3746077,
#  'mastodon.tokyo': 3643814,
#  'fairy.id': 3629844,
#  'expressional.social': 3613162,
#  'aus.social': 3593440,
#  'mastodon.scot': 3560692,
#  'beige.party': 3507296,
#  'mastodon.green': 3494069,
#  'machikadon.online': 3453395,
#  'mastodon.art': 3384295,
#  'www.mastodon.scot': 3311115,
#  'social.tchncs.de': 3166035,
#  'mstdn-jp.site': 3130128,
#  'mastodon.de': 3018977,
#  'indieweb.social': 2946488,
#  'mastodon.ie': 2934347,
#  'nerdculture.de': 2925034,
#  'zirk.us': 2896412,
#  'mastodon.gamedev.place': 2854980,
#  'ieji.de': 2854440,
#  'kmy.blue': 2759151,
#  'mastodon.nl': 2750959,
#  'noc.social': 2696807,
#  'ioc.exchange': 2683386,
#  'mikumikudance.cloud': 2640955,
#  'g0v.social': 2587685,
#  'mastodon.uno': 2579795,
#  'piaille.fr': 2578765,
#  'astronomy.social': 2505805,
#  'mastodon.au': 2498465,
#  'norden.social': 2444913,
#  'mathstodon.xyz': 2412339,
#  'tabletop.vip': 2395283,
#  'twit.social': 2383564,
#  'me.dm': 2311485,
#  'fediscience.org': 2302731,
#  'mastodon.nu': 2300219,
#  'furry.energy': 2290314,
#  'kiritan.work': 2266020,
#  'wandering.shop': 2261582,
#  'hostux.social': 2259501,
#  'mementomori.social': 2207179,
#  'moth.social': 2196087,
#  'defcon.social': 2118171,
#  'ravenation.club': 2103734,
#  'muenchen.social': 2090232,
#  'toad.social': 2076735,
#  'mastodon.nz': 2074137,
#  'nrw.social': 2032739,
#  'med-mastodon.com': 1998299,
#  'sueden.social': 1985493,
#  'geekdom.social': 1955304,
#  'vtdon.com': 1952865,
#  'toot.wales': 1877559,
#  'urbanists.social': 1866885,
#  'pokemon.mastportal.info': 1866502,
#  'layer8.space': 1842063,
#  'det.social': 1839977,
#  'social.cologne': 1832250,
#  'union.place': 1807338,
#  'blueplanet.social': 1758640,
#  'stranger.social': 1751429,
#  'social.nofftopia.com': 1750262,
#  'mastodonbooks.net': 1730970,
#  'lor.sh': 1725380,
#  'hear-me.social': 1713176,
#  'gearheads.social': 1703098,
#  'mstdn.poyo.me': 1695962,
#  'hcommons.social': 1693638,
#  'dice.camp': 1677838,
#  'writing.exchange': 1676107,
#  'mstdn.plus': 1672483,
#  'dmv.community': 1670156,
#  'ruhr.social': 1665575,
#  'cryptodon.lol': 1658079,
#  'digitalcourage.social': 1632549,
#  'strangeminds.social': 1629022,
#  'phpc.social': 1607624,
#  'masto.nu': 1587065,
#  'framapiaf.org': 1584842,
#  'mstdn.games': 1579727,
#  'mastodon.me.uk': 1577603,
#  'bolha.us': 1550289,
#  'mstdn.science': 1549748,
#  'mstdn.maud.io': 1539814,
#  'jorts.horse': 1539645,
#  'mastodon.coffee': 1538603,
#  'hessen.social': 1535869,
#  'ani.work': 1503375,
#  'tilde.zone': 1501137,
#  'mastodon.bida.im': 1491747,
#  'm6n.onsen.tech': 1483145,
#  'lgbtqia.space': 1479140,
#  'masto.pt': 1478863,
#  'cr8r.gg': 1472134,
#  'rivals.space': 1465336,
#  'socel.net': 1461389,
#  'glasgow.social': 1455388,
#  'vocalodon.net': 1452770,
#  'sunny.garden': 1439932,
#  'awscommunity.social': 1431346,
#  'tooting.ch': 1423106,
#  'catswords.social': 1396346,
#  'globalskywatch.social': 1382863,
#  'mastodon.trueten.de': 1377749,
#  'mcr.wtf': 1371292,
#  'dragonscave.space': 1369101,
#  'otadon.com': 1368068,
#  'meow.social': 1365542,
#  'berlin.social': 1358374,
#  'utter.online': 1356652,
#  'sciences.social': 1355493,
#  'kind.social': 1342684,
#  'musician.social': 1332679,
#  'federated.press': 1322666,
#  'swiss.social': 1310346,
#  'animal-crossing.mastportal.info': 1304491,
#  'theblower.au': 1290331,
#  'ruby.social': 1287341,
#  'techforgood.social': 1285050,
#  'mozilla.social': 1272841,
#  'pnw.zone': 1268733,
#  'mastodon.uy': 1268485,
#  'digipres.club': 1266520,
#  'equestria.social': 1265079,
#  'wxw.moe': 1264587,
#  'neurodifferent.me': 1248418,
#  'ecoevo.social': 1238842,
#  'botsin.space': 1236325,
#  'scicomm.xyz': 1230964,
#  'im-in.space': 1227014,
#  'epicure.social': 1217219,
#  'retro.pizza': 1210433,
#  'meerjungfrauengrotte.de': 1204426,
#  'river.group.lt': 1198529,
#  'toots.nu': 1186420,
#  'gaygeek.social': 1185834,
#  'sigmoid.social': 1181225,
#  'lounge.town': 1180946,
#  'umaikebab.xyz': 1173246,
#  'neovibe.app': 1172376,
#  'lepoulsdumonde.com': 1170358,
#  'transfur.social': 1169754,
#  'witches.live': 1169323,
#  'shakedown.social': 1166790,
#  'libretooth.gr': 1157008,
#  'mastouille.fr': 1149610,
#  'social.dev-wiki.de': 1149383,
#  'mastodon.cr': 1132539,
#  'wetdry.world': 1129338,
#  'masto.yttrx.com': 1119264,
#  'social.mikutter.hachune.net': 1115380,
#  'earthstream.social': 1096936,
#  'mstdn.mx': 1095309,
#  'toot.bldrweb.org': 1094157,
#  'liberdon.com': 1093849,
#  'bitbang.social': 1092454,
#  'toot.bike': 1089972,
#  'aethy.com': 1088925,
#  'bildung.social': 1087288,
#  'cyberplace.social': 1083590,
#  'mountains.social': 1065177,
#  'famichiki.jp': 1056204,
#  'rss-mstdn.studiofreesia.com': 1055345,
#  'syringa.social': 1051532,
#  'oldbytes.space': 1049000,
#  'snabelen.no': 1045632,
#  'birdon.social': 1045505,
#  'toot.blue': 1033909,
#  'blacktwitter.io': 1021202,
#  'open3dlab.social': 1017182,
#  'econtwitter.net': 1003418,
#  'sakurajima.moe': 995772,
#  'elonsucks.org': 994550,
#  'mastodon.bayern': 993954,
#  'darkfriend.social': 991499,
#  'mas.corq.co': 986894,
#  'gamepad.club': 982748,
#  'kanoa.de': 979424,
#  'lsbt.me': 978805,
#  'hispagatos.space': 962673,
#  'techtoots.com': 961476,
#  'historians.social': 957580,
#  'mastodon.radio': 957198,
#  'oslo.town': 956058,
#  'corteximplant.com': 946503,
#  'mapstodon.space': 943683,
#  'discordian.social': 939247,
#  'vis.social': 934516,
#  'toot.aquilenet.fr': 931076,
#  'bark.lgbt': 926328,
#  'mastodon.com.pl': 922526,
#  'freiburg.social': 919031,
#  'chitter.xyz': 914941,
#  'peoplemaking.games': 911710,
#  'glauca.space': 911397,
#  'federate.social': 911281,
#  'hometech.social': 906129,
#  'mastodon.acm.org': 904827,
#  'musicworld.social': 903955,
#  'rollenspiel.social': 903847,
#  'eupolicy.social': 903514,
#  'sociale.network': 902349,
#  'nyanya.net': 900870,
#  'autistics.life': 900249,
#  'nightcord.de': 899583,
#  'squawk.mytransponder.com': 898801,
#  'furry.engineer': 893634,
#  'social.horrorhub.club': 885947,
#  'mastodon-belgium.be': 883518,
#  'horrorhub.club': 882178,
#  'astrodon.social': 881831,
#  'medibubble.org': 870693,
#  'literatur.social': 866558,
#  'nfld.me': 860281,
#  'bonn.social': 858278,
#  'openbiblio.social': 856423,
#  'emacs.ch': 855476,
#  'livellosegreto.it': 855306,
#  'romancelandia.club': 854350,
#  'cyberfurz.social': 848939,
#  'en.osm.town': 847512,
#  'opencoaster.net': 844518,
#  'growers.social': 843765,
#  'esq.social': 842368,
#  'graphics.social': 836718,
#  'floofy.tech': 836178,
#  'paquita.masto.host': 832697,
#  'cosocial.ca': 832272,
#  'mastodon.energy': 832086,
#  'social.sdf.org': 824254,
#  'clockwork.monster': 812502,
#  'computerfairi.es': 809175,
#  'pony.social': 807123,
#  'handon.club': 802465,
#  'dizl.de': 796012,
#  'mastodon.juggler.jp': 795216,
#  'tldr.nettime.org': 793640,
#  'sauropods.win': 786515,
#  'xarxa.cloud': 785312,
#  'selfhosted.cafe': 784552,
#  'genomic.social': 782092,
#  'rheinneckar.social': 780446,
#  'glammr.us': 777780,
#  'netsphere.one': 764872,
#  'mastodon.com.py': 761646,
#  'odakyu.app': 760576,
#  'mastdn.social': 756537,
#  'functional.cafe': 751990,
#  'gruene.social': 751216,
#  'toot.funami.tech': 750548,
#  'mstdn.tamag.org': 747622,
#  'pkm.social': 740916,
#  'hci.social': 740385,
#  'mona.do': 740335,
#  'm.ai6yr.org': 739111,
#  'merveilles.town': 734670,
#  'toot.lv': 733326,
#  'discuss.systems': 726652,
#  'bookstodon.com': 722219,
#  'drumstodon.net': 721422,
#  'bologna.one': 717826,
#  'mast.hpc.social': 711124,
#  'xreality.social': 705812,
#  'homoo.social': 702153,
#  'norcal.social': 698683,
#  'mastodon.com.tr': 693651,
#  'gochisou.photo': 687364,
#  'tuiter.rocks': 685974,
#  'airwaves.social': 683925,
#  'woof.group': 680495,
#  'blorbo.social': 672123,
#  'fnordon.de': 672085,
#  'mastodonczech.cz': 670627,
#  'nso.group': 669446,
#  'techpolicy.social': 665193,
#  'alaskan.social': 663430,
#  'acg.mn': 660991,
#  'graz.social': 660253,
#  'mstdn.kemono-friends.info': 658815,
#  'muenster.im': 652712,
#  'masto.bike': 649539,
#  'h-net.social': 649245,
#  'darmstadt.social': 647451,
#  'heads.social': 645737,
#  'friendsofdesoto.social': 645553,
#  'pol.social': 642164,
#  'bangdream.space': 635647,
#  'kinky.business': 633409,
#  'mastodon.opencloud.lu': 633027,
#  'social.seattle.wa.us': 632319,
#  'jasette.facil.services': 629478,
#  'atheopagan.net': 626669,
#  'assemblag.es': 626193,
#  'fed.sbcloud.cc': 625690,
#  'jawns.club': 623551,
#  'synapse.cafe': 619719,
#  'c7.io': 617752,
#  'social.veraciousnetwork.com': 617242,
#  'gardenstate.social': 615962,
#  'tweesecake.social': 614479,
#  'mastodon.tetaneutral.net': 610116,
#  'musicians.today': 609774,
#  'social.sciences.re': 606626,
#  'urusai.social': 605080,
#  'h4.io': 596823,
#  'agilealliance.social': 596777,
#  'okla.social': 596340,
#  'bbq.snoot.com': 596009,
#  'kurage.cc': 593879,
#  'privacyofficers.social': 593616,
#  '4bear.com': 592904,
#  'mastodon.gal': 587794,
#  'tooot.im': 586793,
#  'woof.tech': 579404,
#  'mastodon-swiss.org': 577767,
#  'lile.cl': 577062,
#  'mastodon.catgirl.cloud': 571889,
#  'masto.globaleas.org': 569808,
#  'a2mi.social': 568123,
#  'lingo.lol': 567559,
#  'mastodon.design': 565692,
#  'androiddev.social': 564055,
#  'kemonodon.club': 563629,
#  'mastodon.acc.sunet.se': 557684,
#  'poweredbygay.social': 554900,
#  'kopimi.space': 553958,
#  'toot.lgbt': 549066,
#  'sciencemastodon.com': 548319,
#  'mastodon.education': 547364,
#  'fulda.social': 545919,
#  'allthingstech.social': 545371,
#  'creativewriting.social': 544136,
#  'mofu.kemo.no': 539670,
#  'dragon-fly.club': 538262,
#  'mast.dragon-fly.club': 537526,
#  'bne.social': 536357,
#  'spacey.space': 536089,
#  'corneill.es': 535630,
#  'donphan.social': 532263,
#  'uwu.social': 531474,
#  'toot.berlin': 530314,
#  'dobbs.town': 526161,
#  'theatl.social': 522678,
#  'mastodon-uk.net': 519594,
#  'mastodon.hams.social': 517275,
#  'social.chinwag.org': 516577,
#  'thecentralfinitecurve.com': 516164,
#  'pawb.fun': 515976,
#  'pravda.me': 514759,
#  'drupal.community': 514003,
#  'swiss-talk.net': 513823,
#  'archaeo.social': 506055,
#  'kabedon.space': 504412,
#  'vt.social': 498320,
#  'planet.moe': 497709,
#  'girldick.gay': 496353,
#  'social.boom.army': 495615,
#  'witter.cz': 494210,
#  'masto.nyc': 482519,
#  'masto.bcan.org': 482084,
#  'kirche.social': 481352,
#  'hoosier.social': 478274,
#  'clj.social': 477275,
#  'mastodon.cipherbliss.com': 475799,
#  'machteburch.social': 474306,
#  'mastodon.la': 474270,
#  '23.illuminati.org': 471276,
#  'mograph.social': 467549,
#  'towns.gay': 466320,
#  'typo.social': 463018,
#  'pgh.social': 459154,
#  'opalstack.social': 458690,
#  'm.einverne.info': 456577,
#  'imastodon.net': 455807,
#  'uri.life': 455148,
#  'mastodon.arch-linux.cz': 452805,
#  'mstdn.sublimer.me': 449604,
#  'merovingian.club': 447443,
#  'linernotes.club': 443885,
#  'mastodonsweden.se': 443023,
#  'beach.city': 438979,
#  'toots.matapacos.dog': 438899,
#  'metrobus.masto.host': 438049,
#  'mastodon.cisti.org': 434876,
#  'journodon.com': 434163,
#  'dotnet.social': 433815,
#  'wikis.world': 433492,
#  'handmade.social': 433205,
#  'ellis.social': 433084,
#  'social.ridetrans.it': 432387,
#  'puntarella.party': 429781,
#  'oc.todon.fr': 420663,
#  'tzcafe.com': 419695,
#  'social.sndevs.com': 419282,
#  'raphus.social': 413621,
#  'mastodon.pirati.cz': 412333,
#  'technodon.org': 411638,
#  'genealysis.social': 407628,
#  'mastodonmusic.social': 403998,
#  'furries.club': 402972,
#  'foresdon.jp': 402698,
#  'worldkey.io': 402637,
#  'leftist.network': 401222,
#  'data-folks.masto.host': 399730,
#  'triangletoot.party': 397842,
#  'wehavecookies.social': 397042,
#  'conversafiada.net': 396499,
#  'thicc.horse': 395627,
#  'regenerate.social': 394942,
#  'tribe.net': 394628,
#  'mastobate.social': 394355,
#  'sachsen-medien.social': 394003,
#  'aleph.land': 393126,
#  'epistolary.org': 392355,
#  'mstdn.es': 387006,
#  'kinkyelephant.com': 384854,
#  'akademienl.social': 373910,
#  'mastodon.africa': 373782,
#  'library.love': 371703,
#  'mastodon.lawprofs.org': 369899,
#  'pounced-on.me': 368045,
#  'swecyb.com': 362727,
#  'zug.network': 361724,
#  'rubber.social': 360621,
#  'iosdev.space': 356493,
#  'enshittification.social': 355650,
#  'idlethumbs.social': 349206,
#  'mastodon.com.br': 348189,
#  'podcastindex.social': 344949,
#  'datasci.social': 343400,
#  'm.webtoo.ls': 340694,
#  'front-end.social': 338956,
#  'sonomu.club': 338925,
#  'eimtbigd-masto.techlab.uoc.edu': 336693,
#  'planetearth.social': 334336,
#  'ludosphere.fr': 333349,
#  'systerserver.town': 333073,
#  'pravdasocial.net': 329491,
#  'frankfurt.social': 328473,
#  'pebble.social': 327530,
#  'songbird.cloud': 326938,
#  'cloud-native.social': 326865,
#  'f.cz': 325668,
#  'kopiti.am': 324919,
#  'lgbt.io': 322665,
#  'mastodon.bits-und-baeume.org': 319313,
#  'geekstodon.com': 315185,
#  'lou.lt': 315167,
#  'smutlandia.com': 315115,
#  'recurse.social': 312539,
#  'unbound.social': 312452,
#  'fedisabled.social': 312140,
#  'toot.portes-imaginaire.org': 310625,
#  'mastodon.tedomum.net': 310520,
#  'speedlines.stctp.zone': 308398,
#  'guitar.rodeo': 308385,
#  'esperanto.masto.host': 307760,
#  'mastorol.es': 306297,
#  'mast.eu.org': 304857,
#  'mastoot.fr': 303385,
#  'mastodon.nzoss.nz': 302414,
#  'aoir.social': 301168,
#  'bahn.social': 298522,
#  'mastodon.bsd.cafe': 297173,
#  'gayfr.social': 296623,
#  'elekk.xyz': 294793,
#  'die-partei.social': 293275,
#  'freeatlantis.com': 292576,
#  'rebel.ar': 289728,
#  'md.ilyamikcoder.com': 289469,
#  'aschaffenburg.social': 289080,
#  'social.silicon.moe': 287679,
#  'mastodon.thirring.org': 286473,
#  'gametoots.de': 286275,
#  'net4sw.com': 286015,
#  'jazztodon.com': 284357,
#  'mastodon.motcha.tech': 280677,
#  'ruhrpott.social': 280349,
#  'arsenalfc.social': 279703,
#  'tooter.social': 278656,
#  'social.sp-codes.de': 278165,
#  'colearn.social': 278153,
#  'social.spejset.org': 277537,
#  'mstdn.osaka': 277342,
#  'weremember.social': 276553,
#  'cville.online': 274720,
#  'paktodon.asia': 273094,
#  'indieauthors.social': 271456,
#  'gulp.cafe': 268770,
#  'pointless.chat': 267577,
#  'mustard.blog': 267571,
#  'vermont.masto.host': 267485,
#  'osna.social': 267395,
#  'glaceon.social': 267341,
#  'esoteric.party': 266794,
#  'metalverse.social': 266368,
#  'rcsocial.net': 265650,
#  'friends.cafe': 265568,
#  'apobangpo.space': 263303,
#  'beta.qdon.space': 262755,
#  '3615.computer': 261154,
#  'd-64.social': 260694,
#  'gamingjp.org': 257861,
#  'silversword.online': 256828,
#  'solarpunk.moe': 249859,
#  'feuerwehr.social': 249561,
#  'vrcjp.hostdon.ne.jp': 248945,
#  'gamedev.lgbt': 248667,
#  'mstdn.in.th': 246666,
#  'nederland.online': 245701,
#  'qdon.space': 245025,
#  'trekkies.social': 243017,
#  'aipi.social': 242642,
#  'tchafia.be': 242505,
#  'ifwo.eu': 242363,
#  'dariox.club': 240214,
#  '9kb.me': 239585,
#  'quakers.social': 238894,
#  'zhub.link': 238321,
#  'wobbl.xyz': 237468,
#  'orchard.social': 237306,
#  'dftba.club': 235550,
#  'cultofshiv.wtf': 234040,
#  'arvr.social': 233715,
#  'super-gay.co': 233196,
#  'mastodon.cat': 231222,
#  'norrebro.space': 230994,
#  'oulipo.social': 230302,
#  'fluffs.au': 229617,
#  'systemli.social': 228889,
#  'jvm.social': 224610,
#  'social.kryta.app': 224547,
#  'epsilon.social': 223303,
#  'julialang.social': 221537,
#  'mastodon.beer': 221206,
#  'fedinerds.social': 221158,
#  'batchats.net': 221082,
#  'muri.network': 216940,
#  'leipzig.town': 214935,
#  'rap.social': 211560,
#  'suma-ev.social': 211048,
#  'anime.kona.moe': 209181,
#  'plantex.top': 209164,
#  'bakedbean.xyz': 208393,
#  'pdx.sh': 208021,
#  'mathtod.online': 207579,
#  'furs.social': 207323,
#  'iaccessibility.social': 205934,
#  'mastodon.pnpde.social': 205400,
#  'dragonchat.org': 205039,
#  'owo.cafe': 205035,
#  'wspanialy.eu': 205017,
#  'pieville.net': 203078,
#  'wank.social': 202792,
#  'nebbia.fail': 202432,
#  'kzoo.to': 202377,
#  'gensokyo.town': 200893,
#  'bayes.club': 200376,
#  'arkm.social': 199907,
#  'social.audiovalentine.com': 199705,
#  'snaggletooth.life': 199255,
#  'comunidad.nvda.es': 197594,
#  'aut.social': 197427,
#  'satanodon.com': 197342,
#  'toot.re': 195735,
#  'wisskomm.social': 195671,
#  'lewacki.space': 194484,
#  'est.social': 194344,
#  'wargamers.social': 194314,
#  'mastodon.hk': 191527,
#  'social.slat.org': 190942,
#  'ayom.media': 190226,
#  'rail.chat': 189351,
#  'mastodon.bachgau.social': 186654,
#  'graeber.social': 186049,
#  'warhammer.social': 186016,
#  'irsoluciones.social': 185929,
#  'trans.house': 185803,
#  'social.restless.systems': 185671,
#  'sauna.social': 184103,
#  'h5q.net': 183801,
#  'fairmove.net': 183401,
#  'camp.smolnet.org': 181279,
#  'mastodon.oeru.org': 180754,
#  'bzh.social': 180559,
#  'leftodon.social': 179337,
#  'normal.style': 178520,
#  'podvibes.co': 177871,
#  'parfait.day': 177712,
#  'cultur.social': 177365,
#  'linux.social': 176983,
#  'freie-re.de': 176586,
#  'abdl.link': 176048,
#  'blimps.xyz': 175983,
#  'www.blimps.xyz': 175389,
#  'trpg-o.xyz': 175152,
#  'mascodon.jp': 174442,
#  'squawk.social': 173234,
#  'mstdn.guru': 172874,
#  'pone.social': 171980,
#  'travelpandas.fr': 171344,
#  't.chadole.com': 170900,
#  'mastodon.mnetwork.co.kr': 170450,
#  'shark.community': 169686,
#  'splat00n.ink': 168807,
#  'birdbutt.com': 168745,
#  'fikaverse.club': 168662,
#  'oliphaunt.social': 167314,
#  'folksocial.org': 165953,
#  'seocommunity.social': 165534,
#  'a11y.social': 164985,
#  'drk.network': 161514,
#  'kinkycats.org': 160791,
#  'fashionsocial.host': 160316,
#  'mastodon.triggerphra.se': 160190,
#  'vocalounge.cafe': 158641,
#  'elizur.me': 158325,
#  'bunt.social': 157063,
#  'energiewende.social': 154783,
#  'top-netz.de': 154385,
#  'indiehackers.social': 154046,
#  'critcare.social': 153999,
#  'iwatedon.net': 153058,
#  'mstdn.tokyocameraclub.com': 152307,
#  'ika.queloud.net': 150326,
#  'lazysocial.de': 150124,
#  'fim.social': 149594,
#  'mastodon.sk': 149395,
#  'w3c.social': 149116,
#  'social.bim.land': 147094,
#  'gnulinux.social': 145870,
#  'federatedfandom.net': 145214,
#  'krigskunst.social': 143484,
#  'fanfare.horse': 143374,
#  'mastodon.hypnoguys.com': 142160,
#  'cubhub.social': 141239,
#  'helmholtz.social': 140107,
#  'libori.social': 138929,
#  'kpop.social': 137006,
#  'livester.net': 136439,
#  'tinnies.club': 135142,
#  'colorid.es': 134935,
#  'stereodon.social': 134810,
#  'skastodon.com': 134621,
#  'illo.social': 133246,
#  'mastodon.boston': 132308,
#  'occitania.social': 132141,
#  'indg.club': 131745,
#  'mastodon.tn': 131600,
#  'burma.social': 130432,
#  'noods.fun': 128540,
#  'alpaka.social': 128048,
#  'rockcd.jp': 127728,
#  'mastodon.pl': 126567,
#  'biologists.social': 126107,
#  'woofy.social': 125937,
#  'social.apreslanu.it': 125673,
#  'nitiasa.com': 125453,
#  'electroverse.tech': 125345,
#  'persiansmastodon.com': 124812,
#  'astral.camp': 124433,
#  'social.ferrocarril.net': 124387,
#  'samenet.social': 124077,
#  'franken.social': 123504,
#  'edumasto.org': 123304,
#  'social.ds106.us': 123134,
#  'red.niboe.info': 122915,
#  'localization.cafe': 122517,
#  'pouet.fedi.quebec': 122438,
#  'publicgood.social': 121866,
#  'photodn.net': 121813,
#  'social.nekover.se': 121710,
#  'oomfie.city': 121507,
#  'jit.social': 120288,
#  'seo.chat': 119859,
#  'aipub.social': 119796,
#  'mastodon.ph': 118908,
#  'mastodon.holeyfox.co': 117526,
#  'dotgr.id': 117061,
#  'social.sdfeu.org': 116272,
#  'metalhead.club': 115949,
#  'k8s.social': 114487,
#  'lviv.social': 114453,
#  'toulouse.social': 114052,
#  'milliways.social': 114021,
#  'nomanssky.social': 113470,
#  'vkl.world': 112523,
#  'snailedit.social': 112213,
#  'mastodonsuomi.fi': 111439,
#  'rodent.life': 110698,
#  'mastodon.escepticos.es': 110612,
#  'social.esmarconf.org': 110523,
#  'beamship.mpaq.org': 110043,
#  'poliversity.it': 109961,
#  'burnthis.town': 107800,
#  'kommunismus.social': 107038,
#  'rva.fyi': 106451,
#  'social.moment.at': 106291,
#  'yapstreams.com': 105455,
#  'foojay.social': 104986,
#  'mastodon.mg': 104754,
#  'ljs.social': 103750,
#  'moessingen.social': 103732,
#  'social.darc.de': 103355,
#  'mastodon.bv.linksjugend-solid.de': 103115,
#  'mas.atmx.ca': 102699,
#  'alpaca.gold': 102018,
#  'page.lgbt': 101905,
#  'neomobius.com': 99622,
#  'wiesbaden.social': 99599,
#  'digitalpioneers.social': 98441,
#  'chaotic.social': 96830,
#  'karlsruhe.social': 96007,
#  'streamers.social': 95819,
#  'avgeek.social': 95594,
#  'lajna.si': 95455,
#  'degrowth.social': 95086,
#  'lincolnite.net': 94626,
#  'socialclub.nyc': 94294,
#  'devianze.city': 93090,
#  'ffxiv-mastodon.com': 92915,
#  'linke.social': 90787,
#  'radikal.social': 89862,
#  'mastodon.frl': 89787,
#  'tuebingen.network': 89338,
#  'leds.social': 89250,
#  'nashtodon.com': 88528,
#  'ukrainian.network': 87823,
#  'tux.social': 87333,
#  'lipn.info': 86750,
#  'craba.cab': 86700,
#  'v2br.social': 86156,
#  'social.cu2d.com': 85546,
#  'unvernunft.social': 84163,
#  'hameln.social': 83705,
#  'eggplant.social': 83582,
#  'plushies.social': 83459,
#  'app.bikers.social': 82731,
#  'dataplatform.social': 82378,
#  'mastodon.furrypaws.cc': 82090,
#  'lehrerzimmer.social': 81910,
#  'toki.social': 81839,
#  '3dp.chat': 81596,
#  'mastodon.economiasocial.org': 81209,
#  'social.1up.ninja': 81200,
#  'argon.city': 81005,
#  'bhre.social': 80951,
#  'reliverse.social': 79758,
#  'spojnik.works': 79337,
#  'computer-club.online': 79254,
#  'mastodon.hosnet.fr': 78652,
#  'social.globalpirates.net': 78531,
#  'spd.social': 78506,
#  'academiccloud.social': 76896,
#  'comics.town': 75833,
#  'mastodon.quebec': 75693,
#  'blackrocks.social': 75580,
#  'bkcastle.net': 74802,
#  'gaminginthe.cloud': 74785,
#  'mastodon.cl': 73939,
#  'blogi.social': 73605,
#  'body.social': 73481,
#  'mastodon.schule': 73153,
#  'hed.im': 73141,
#  'mapsupport.de': 72049,
#  'fpl.social': 72044,
#  'nwb.social': 71848,
#  'redgate.social': 71221,
#  'webperf.social': 71020,
#  'securitycafe.ca': 70998,
#  'nfdi.social': 70986,
#  'screencastsonline.social': 69374,
#  'mastodon.ee': 69323,
#  'sportsfeed.me': 69120,
#  'puppo.space': 67224,
#  'mastodon.jalgi.eus': 67017,
#  'archaeology.social': 66684,
#  'esglife.social': 65721,
#  'ist-ur.org': 65200,
#  'forum-lucifer.com': 65188,
#  'guild.pmdcollab.org': 65187,
#  'recht.social': 64590,
#  'freesocial.co': 63977,
#  'toot.works': 63561,
#  'social.diva.exchange': 63181,
#  'social.sunet.se': 62526,
#  'feedbeat.me': 61642,
#  'toot.gnous.eu': 61632,
#  'gaydadon.jp': 60773,
#  'social.dino.icu': 60110,
#  'retrogaming.social': 59948,
#  'humber.news': 59014,
#  'fedi.lat': 58538,
#  'meow.cloud': 57358,
#  'social.uibk.ac.at': 57199,
#  'genealogie.social': 56656,
#  'redpawcollective.co': 56434,
#  'technews.social': 55633,
#  'india.goonj.xyz': 55612,
#  'ap.ketsuben.red': 55372,
#  'mamut.social': 55189,
#  'f-ckendehoelle.de': 54920,
#  'masto.kreks.nl': 54277,
#  'tu.social': 54103,
#  'mahiradon.com': 53999,
#  'gay.camera': 53393,
#  'mastodon.librelabucm.org': 52493,
#  'frogs.lgbt': 52407,
#  'mrnet.pt': 52138,
#  'mstdn.myifn.de': 51825,
#  'manitu.social': 50792,
#  'opensimsocial.com': 49358,
#  '3zi.ru': 49333,
#  'avantwhatever.org': 48863,
#  'nasface.cz': 48578,
#  'mastodon.cesko.digital': 48507,
#  'clube.social': 46286,
#  'saptodon.org': 46151,
#  'wokka.be': 46041,
#  'riin.fr': 45965,
#  'brands.town': 45856,
#  'nc.social': 43940,
#  'mastodon.vanlife.is': 43718,
#  'mcyt.cc': 43010,
#  'indieapps.space': 41857,
#  'pogs.cafe': 41057,
#  'blackrock.city': 40812,
#  'torontodiy.xyz': 40507,
#  'klog.tw': 40488,
#  'dpw.social': 40426,
#  'liker.social': 40239,
#  'forgi.social': 40221,
#  'mstdn.md': 39998,
#  'dtp-mstdn.jp': 39698,
#  'mastodon.conquestuniverse.com': 39520,
#  'umbracocommunity.social': 39006,
#  'spezi.social': 38209,
#  'mostodon.de': 37502,
#  'piano.masto.host': 35820,
#  'mastodon.mikmak.cc': 35278,
#  'prf.me': 34631,
#  'zenzone.social': 34458,
#  'vtuber.house': 33975,
#  'yeen.exposed': 33928,
#  'bear.community': 33704,
#  'senigallia.one': 33203,
#  'lust4love.eu.org': 32065,
#  'publishing.social': 31876,
#  'squeak.social': 31340,
#  'toot.lugbz.social': 31278,
#  'hypno.social': 30727,
#  'mastodon.heavymusic.rocks': 29957,
#  'babyfurs.social': 29796,
#  'niedersachsen.social': 29438,
#  'displayeurope.social': 29133,
#  'jidaar.net': 28721,
#  'emilcar.social': 28594,
#  'friends.librescrum.org': 27978,
#  'ponies.social': 27493,
#  'mastodon.thenewoil.org': 26742,
#  'qn.krig.jp': 25014,
#  'anticapitalista.it': 24543,
#  'zpravobot.news': 24417,
#  'social.panic.com': 24149,
#  'e.fo': 24054,
#  'mastodon.progaccess.net': 23825,
#  'nluug.social': 23778,
#  'daydream.ink': 22827,
#  'social.thewhole.site': 22325,
#  'link.baai.ac.cn': 22263,
#  'social.overheid.nl': 22258,
#  'zh.pp.social': 21765,
#  'blips2.club': 21511,
#  'mastodon.scollectif.fr': 21330,
#  'social.garudalinux.org': 21242,
#  'social.franco.net.eu.org': 20755,
#  'mesmerized.online': 20606,
#  'social.butnot.today': 20531,
#  'mastodon.ethibox.fr': 19679,
#  'solarcene.community': 19337,
#  'toot.krinetzki.de': 19296,
#  'social.jcs-net.de': 19185,
#  'vivere.uno': 19110,
#  'nicuverse.org': 18678,
#  'mastodon.jj5fxl.net': 18565,
#  'exito.social': 18334,
#  'bumscode.com': 18294,
#  'restraint.social': 17766,
#  'ciecuo.club': 17632,
#  'pocketpixels.club': 17341,
#  'mastodon.cloudsecurityofficehours.com': 17095,
#  'sizecraft.social': 16951,
#  'don.neet.co.jp': 16218,
#  'social.schleswig-holstein.de': 15153,
#  'social.ftm.nl': 14850,
#  'torguard.social': 14624,
#  'home.speakfree.social': 14607,
#  'dimsumdams.xyz': 14193,
#  'paravielfalt.zone': 14189,
#  'blockriot.com': 14067,
#  'barkclub.xyz': 14035,
#  'blue-sky.world': 14030,
#  'mastodon.bot': 13758,
#  'zone.liolok.com': 13672,
#  'social.cs.swarthmore.edu': 13005,
#  'verkehrswende.social': 12830,
#  'mastodon.twictee.org': 12734,
#  'bibletalk.social': 12458,
#  'ecologie.social': 12276,
#  'gervtuber.de': 11498,
#  'xno.social': 11149,
#  'mast.shitpostbot.com': 10600,
#  'tombraidersocial.com': 10342,
#  'toot.rebel.ar': 10117,
#  'fedi.halcyon-is.land': 9234,
#  'amicale.net': 8535,
#  'social.liip.ch': 8130,
#  'activitypub.academy': 7798,
#  'gdcm.space': 7657,
#  'saronno.one': 7610,
#  'surus.keepcoding.io': 7122,
#  'weatherby2378.social': 6962,
#  'iztasocial.site': 6747,
#  'communist.accountant': 5894,
#  'social.y-gallery.net': 5819,
#  'toot.fedispace.eu': 5254,
#  'mastodon.bergen.social': 5155,
#  'mastodon.acerbo.me': 5054,
#  'mastodon.infodocs.eu': 4701,
#  'penguicon.social': 4463,
#  'fandomonium.space': 4439,
#  'protogen.social': 4378,
#  'mtgjudge.social': 4255,
#  'webxr.social': 4170,
#  'unipar.online': 4111,
#  'srilankans.online': 3638,
#  'hunterlife.net': 3547,
#  'mstdn.lt': 3540,
#  'mastodon.nycmesh.net': 3126,
#  'videochina.net': 3050,
#  'zetaspace.org': 3018,
#  'nfb.social': 2954,
#  'sp.kub2091.ru': 2732,
#  'nologo.social': 2722,
#  'todon.ploud.fr': 2628,
#  'mstdn.penguinhub.org': 2515,
#  'thejuniverse.no': 1674,
#  'blueadair.net': 1673,
#  'mstdn.nagito.net': 1450,
#  'freie-radios.org': 1414,
#  'learnk8s.news': 1314,
#  'social.techliminal.com': 1247,
#  'sparrow.cs.uni-magdeburg.de': 1156,
#  'ivory.rosebloom.one': 959,
#  'shotgunlife.social': 894,
#  'kunichogi.icu': 830,
#  'elcofre.social': 769,
#  'wkly.ws': 702,
#  'terra.social': 687,
#  'rfj.social': 627,
#  'social.numerique.gouv.fr': 582,
#  'micc.masto.host': 400,
#  'barkoczy.social': 391,
#  'csu.coffee': 368,
#  'makegayfriends.com': 364,
#  'nicaloro.com': 340,
#  'jsemholkacz.todon.de': 324,
#  ...}

# %%
crawled_federated_counts_search: Search = base_search.params(size=0)\
    .filter(Term(is_local=False))
crawled_federated_counts_search.aggs\
    .bucket(
        "instances",
        PerTerms(field="crawled_from_instance.keyword", size=crawled_instances_count)
    )
    
crawled_federated_counts_buckets = crawled_federated_counts_search.execute().aggs.instances.buckets
crawled_federated_counts = {
    bucket.key: bucket.doc_count
    for bucket in crawled_federated_counts_buckets
}
crawled_federated_counts

# %%
crawled_local_counts_search: Search = base_search.params(size=0)\
    .filter(Term(is_local=True))
crawled_local_counts_search.aggs\
    .bucket(
        "instances",
        PerTerms(field="crawled_from_instance.keyword", size=crawled_instances_count)
    )
    
crawled_local_counts_buckets = crawled_local_counts_search.execute().aggs.instances.buckets
crawled_local_counts = {
    bucket.key: bucket.doc_count
    for bucket in crawled_local_counts_buckets
}
crawled_local_counts

# %%
def save_favicon(instance: str, quiet: bool = False) -> Path | None:
    favicon_path = OUTPUT_PATH / "favicons" / f"favicon-{instance}.png"
    favicon_path.parent.mkdir(parents=True, exist_ok=True)
    if favicon_path.exists():
        return favicon_path
    domain = instance
    if instance.count(".") > 1:
        domain = ".".join(instance.split(".")[-2:])
    if not quiet:
        print(f"Searching for favicon for {domain}...")
    try:
        favicons = get_favicon(f"https://{domain}", timeout=2)
    except Exception:
        return None
    favicons = sorted(favicons, key=lambda f: f.width, reverse=True)
    favicons = [favicon for favicon in favicons if favicon.format == "png"]
    if len(favicons) == 0:
        return None
    if not quiet:
        print(f"Downloading favicon from {domain}...")
    favicon_response = get(favicons[0].url, stream=True, timeout=3)
    try:
        with favicon_path.open("wb") as image:
            for chunk in favicon_response.iter_content(1024):
                image.write(chunk)
    except Exception:
        favicon_path.unlink()
        return None
    return favicon_path

# %%
top10_crawled_instances: list[str] = [
    instance
    for instance, _ in sorted(
        crawled_counts.items(), 
        key=lambda b: b[1],
        reverse=True,
    )[:10]
]
top10_crawled_instances

# %%
crawled_instances = set()
with INSTANCES_PATH.open("r") as file:
    crawled_instances.update(line.strip() for line in file)
with REMOVED_INSTANCES_PATH.open("rb") as file:
    crawled_instances.update(load(file))
crawled_instances
# Out:
# {'avgeek.social',
#  'chaotic.social',
#  'oslo.town',
#  'assemblag.es',
#  'poliversity.it',
#  'muenchen.social',
#  'sfba.social',
#  'mountains.social',
#  'mastodonsweden.se',
#  'tuiter.rocks',
#  'spezi.social',
#  'genealysis.social',
#  'twit.social',
#  'blockriot.com',
#  'tabletop.vip',
#  'social.vivaldi.net',
#  'kurage.cc',
#  'lviv.social',
#  'mstdn.osaka',
#  'iosdev.space',
#  'nerdculture.de',
#  'mastodon.energy',
#  'dizl.de',
#  'literatur.social',
#  'piaille.fr',
#  'tombraidersocial.com',
#  'enshittification.social',
#  'bangdream.space',
#  'awscommunity.social',
#  'kemonodon.club',
#  'mastodon.design',
#  'mindly.social',
#  'toots.matapacos.dog',
#  '60jj.masto.host',
#  'zug.network',
#  'metrobus.masto.host',
#  'tooting.ch',
#  'nederland.online',
#  'xno.social',
#  'ika.queloud.net',
#  'scicomm.xyz',
#  'ioc.exchange',
#  'mast.hpc.social',
#  'sciences.social',
#  'friends.cafe',
#  'solarcene.community',
#  'w3c.social',
#  'mastodon.jalgi.eus',
#  'tooot.im',
#  'parfait.day',
#  'saptodon.org',
#  '23.illuminati.org',
#  'linke.social',
#  'alaskan.social',
#  'dragonscave.space',
#  'indieweb.social',
#  'syringa.social',
#  'arsenalfc.social',
#  'devianze.city',
#  'bologna.one',
#  'bildung.social',
#  'mastodon.ie',
#  'lajna.si',
#  '9kb.me',
#  'darmstadt.social',
#  'lust4love.eu.org',
#  'yapstreams.com',
#  'epsilon.social',
#  'kinky.business',
#  'datasci.social',
#  'mastodon.me.uk',
#  'foresdon.jp',
#  'shotgunlife.social',
#  'blacktwitter.io',
#  'fanfare.horse',
#  'social.jcs-net.de',
#  'mas.atmx.ca',
#  'mastodon.org.uk',
#  'helmholtz.social',
#  'humber.news',
#  'ruby.social',
#  'arvr.social',
#  'pounced-on.me',
#  'snaggletooth.life',
#  'toot.gnous.eu',
#  'tzcafe.com',
#  'mstdn-jp.site',
#  'babyfurs.social',
#  'mstdn.lt',
#  'mastodon.vanlife.is',
#  'illo.social',
#  'mastodon.librelabucm.org',
#  'anticapitalista.it',
#  'mozilla.social',
#  'torontodiy.xyz',
#  'functional.cafe',
#  'social.silicon.moe',
#  'cryptodon.lol',
#  'toot.berlin',
#  'graphics.social',
#  '3dp.chat',
#  'mastodon.bsd.cafe',
#  'wokka.be',
#  'social.sp-codes.de',
#  'archaeology.social',
#  'musicworld.social',
#  'displayeurope.social',
#  'epistolary.org',
#  'indiehackers.social',
#  'bahn.social',
#  'mstdn.business',
#  'pouet.fedi.quebec',
#  'vtuber.house',
#  'social.chinwag.org',
#  'nso.group',
#  'catswords.social',
#  '4bear.com',
#  'mastodon.com.br',
#  'avantwhatever.org',
#  'fairy.id',
#  'bitbang.social',
#  'poweredbygay.social',
#  'freesocial.co',
#  'federated.press',
#  'ivory.rosebloom.one',
#  'troet.cafe',
#  'social.bim.land',
#  'mstdn.nijist.info',
#  'barkclub.xyz',
#  't.chadole.com',
#  'pol.social',
#  'horrorhub.club',
#  'freeatlantis.com',
#  'umaikebab.xyz',
#  'mathstodon.xyz',
#  'fnordon.de',
#  'liberdon.com',
#  'flipboard.social',
#  'splat00n.ink',
#  'thejuniverse.no',
#  'mastodon.com.pl',
#  'imastodon.net',
#  'girldick.gay',
#  'toot.lgbt',
#  'bolha.us',
#  'guild.pmdcollab.org',
#  'k8s.social',
#  'mastodonchina.com',
#  'd-64.social',
#  'chaos.social',
#  'home.speakfree.social',
#  'wehavecookies.social',
#  'jawns.club',
#  'corteximplant.com',
#  'folksocial.org',
#  'airwaves.social',
#  'publishing.social',
#  'torguard.social',
#  'abdl.link',
#  'eggplant.social',
#  'social.boom.army',
#  'e.fo',
#  'feedbeat.me',
#  'social.moment.at',
#  'social.restless.systems',
#  'mastodon.cipherbliss.com',
#  'raphus.social',
#  'lewacki.space',
#  'social.slat.org',
#  'bonn.social',
#  'typo.social',
#  'kzoo.to',
#  'aschaffenburg.social',
#  'androiddev.social',
#  'mastodon.nz',
#  'leipzig.town',
#  'kabedon.space',
#  'esq.social',
#  'social.nekover.se',
#  'smutlandia.com',
#  'phpc.social',
#  'linernotes.club',
#  'localization.cafe',
#  'mastodon.oeru.org',
#  'h-net.social',
#  'securitycafe.ca',
#  'fediscience.org',
#  'bakedbean.xyz',
#  'historians.social',
#  'me.dm',
#  'mastodon.hk',
#  'terra.social',
#  'witter.cz',
#  'opencoaster.net',
#  'toot.works',
#  'h4.io',
#  'river.group.lt',
#  'glammr.us',
#  'kunichogi.icu',
#  'det.social',
#  'gaydadon.jp',
#  'mastodon-uk.net',
#  'esperanto.masto.host',
#  'academiccloud.social',
#  'archaeo.social',
#  'tuebingen.network',
#  'exito.social',
#  'cyberfurz.social',
#  'mastodon.mg',
#  'sp.kub2091.ru',
#  'spd.social',
#  'mstdn.es',
#  'regenerate.social',
#  'graz.social',
#  'mast.dragon-fly.club',
#  'dimsumdams.xyz',
#  'zenzone.social',
#  'moessingen.social',
#  'umbracocommunity.social',
#  'redgate.social',
#  'g0v.social',
#  'social.cs.swarthmore.edu',
#  'squawk.mytransponder.com',
#  'social.kryta.app',
#  'norrebro.space',
#  'lingo.lol',
#  'degrowth.social',
#  'top-netz.de',
#  'craba.cab',
#  'screencastsonline.social',
#  'social.apreslanu.it',
#  'hear-me.social',
#  'data-folks.masto.host',
#  'alpaca.gold',
#  'pawb.fun',
#  'dragonchat.org',
#  'lgbt.io',
#  '3zi.ru',
#  'mastodon.scollectif.fr',
#  'digitalcourage.social',
#  'toki.social',
#  'elonsucks.org',
#  'm.ai6yr.org',
#  'mastodon.trueten.de',
#  'nebbia.fail',
#  'mastodon.education',
#  'mastobate.social',
#  'zpravobot.news',
#  'mastodon.quebec',
#  'mstdn.social',
#  'v2br.social',
#  'ljs.social',
#  'dotnet.social',
#  'pogs.cafe',
#  'toot.krinetzki.de',
#  'gay.camera',
#  'journodon.com',
#  'spacey.space',
#  'hispagatos.space',
#  'skastodon.com',
#  'wikis.world',
#  'mast.eu.org',
#  'm6n.onsen.tech',
#  'mastodon.nu',
#  'sunny.garden',
#  'learnk8s.news',
#  'beige.party',
#  'hed.im',
#  'hunterlife.net',
#  'mastodon.beer',
#  'jsemholkacz.todon.de',
#  'todon.ploud.fr',
#  'zhub.link',
#  'vmst.io',
#  'privacyofficers.social',
#  'beta.qdon.space',
#  'shakedown.social',
#  'satanodon.com',
#  'shao.life',
#  'ayom.media',
#  'universeodon.com',
#  'mastodon.pl',
#  'mastodon.cesko.digital',
#  'mastodon.economiasocial.org',
#  'mrnet.pt',
#  'ffxiv-mastodon.com',
#  'mstdn.science',
#  'tldr.nettime.org',
#  'wandering.shop',
#  'dtp-mstdn.jp',
#  'hcommons.social',
#  'gochisou.photo',
#  'rfj.social',
#  'mastodon.opencloud.lu',
#  'famichiki.jp',
#  'fim.social',
#  'forgi.social',
#  'masto.bcan.org',
#  'mesmerized.online',
#  'social.audiovalentine.com',
#  'mapsupport.de',
#  'wiesbaden.social',
#  'systerserver.town',
#  'mastodon.online',
#  'toot.rebel.ar',
#  'wisskomm.social',
#  'handmade.social',
#  'camp.smolnet.org',
#  'cyberplace.social',
#  'rodent.life',
#  'vivere.uno',
#  'webperf.social',
#  'union.place',
#  'mastodon.acm.org',
#  'moth.social',
#  'zone.liolok.com',
#  'cultur.social',
#  'mastodon.thirring.org',
#  'mstdn.penguinhub.org',
#  'elekk.xyz',
#  'woof.tech',
#  'mastodon.bida.im',
#  'wargamers.social',
#  'mastodonapp.uk',
#  'niedersachsen.social',
#  'autistics.life',
#  'mastodon.au',
#  'mastodon.heavymusic.rocks',
#  'nicaloro.com',
#  'nightcord.de',
#  'toulouse.social',
#  'friends.librescrum.org',
#  'hci.social',
#  'ecologie.social',
#  'wxw.moe',
#  'noc.social',
#  'mamut.social',
#  'chitter.xyz',
#  'bhre.social',
#  'botsin.space',
#  'jazztodon.com',
#  'cr8r.gg',
#  'mastodon.lawprofs.org',
#  'towns.gay',
#  'ellis.social',
#  'allthingstech.social',
#  'blogi.social',
#  'a2mi.social',
#  'mastodon.acc.sunet.se',
#  'mastodonsuomi.fi',
#  'mementomori.social',
#  'opensimsocial.com',
#  'page.lgbt',
#  'tu.social',
#  'link.baai.ac.cn',
#  'uri.life',
#  'wetdry.world',
#  'solidcharity.net',
#  'mahiradon.com',
#  'fulda.social',
#  'puppo.space',
#  'woofy.social',
#  'mastodon.nycmesh.net',
#  'mastodon.uy',
#  'iaccessibility.social',
#  'social.globalpirates.net',
#  'wkly.ws',
#  'chaosfem.tw',
#  'silversword.online',
#  'jorts.horse',
#  'pgh.social',
#  'glasgow.social',
#  'mastodon.bot',
#  'worldkey.io',
#  'mastoot.fr',
#  'ukrainian.network',
#  'astral.camp',
#  'fikaverse.club',
#  'im-in.space',
#  'neomobius.com',
#  'mastodon-belgium.be',
#  'elcofre.social',
#  'pieville.net',
#  'med-mastodon.com',
#  'handon.club',
#  'gdcm.space',
#  'oldbytes.space',
#  'toot.bldrweb.org',
#  'bzh.social',
#  'gearheads.social',
#  'digipres.club',
#  'emilcar.social',
#  'travelpandas.fr',
#  'dataplatform.social',
#  'rollenspiel.social',
#  'unvernunft.social',
#  'mastdn.social',
#  'peoplemaking.games',
#  'c7.io',
#  'creativewriting.social',
#  'freiburg.social',
#  'dpw.social',
#  'gervtuber.de',
#  'fedinerds.social',
#  'qoto.org',
#  'comics.town',
#  'expressional.social',
#  'mustard.blog',
#  'linux.social',
#  'blue-sky.world',
#  'ifwo.eu',
#  'corneill.es',
#  'mstdn.guru',
#  'planetearth.social',
#  'retrogaming.social',
#  'ravenation.club',
#  'social.sciences.re',
#  'drk.network',
#  'otadon.com',
#  'mikumikudance.cloud',
#  'mastodon.world',
#  'econtwitter.net',
#  'speedlines.stctp.zone',
#  'thicc.horse',
#  'masto.nu',
#  'protogen.social',
#  'okla.social',
#  'dragon-fly.club',
#  'puntarella.party',
#  'social.dino.icu',
#  'ani.work',
#  'social.ferrocarril.net',
#  'hometech.social',
#  'clube.social',
#  'leftodon.social',
#  'libretooth.gr',
#  'social.ridetrans.it',
#  'fedibird.com',
#  'mastodonbooks.net',
#  'social.panic.com',
#  'kmy.blue',
#  'dobbs.town',
#  'samenet.social',
#  'masto.nyc',
#  'social.franco.net.eu.org',
#  'social.dev-wiki.de',
#  'fedi.lat',
#  'gamedev.lgbt',
#  'gruene.social',
#  'infosec.exchange',
#  'noods.fun',
#  'nicuverse.org',
#  'geekdom.social',
#  'machikadon.online',
#  'mastodon.hypnoguys.com',
#  'trekkies.social',
#  'tux.social',
#  'squeak.social',
#  'masto.yttrx.com',
#  'm.webtoo.ls',
#  'mastodon.bits-und-baeume.org',
#  'animal-crossing.mastportal.info',
#  'mastorol.es',
#  'musicians.today',
#  'mastouille.fr',
#  'floofy.tech',
#  'openbiblio.social',
#  'lile.cl',
#  'bookstodon.com',
#  'bayes.club',
#  'social.seattle.wa.us',
#  '3615.computer',
#  'glaceon.social',
#  'toot.bike',
#  'xreality.social',
#  'radikal.social',
#  'arkm.social',
#  'daydream.ink',
#  'videochina.net',
#  'paravielfalt.zone',
#  'urbanists.social',
#  'metalverse.social',
#  'wank.social',
#  'wobbl.xyz',
#  'mastodon.mnetwork.co.kr',
#  'bunt.social',
#  'social.uibk.ac.at',
#  'dmv.community',
#  'persiansmastodon.com',
#  'plantex.top',
#  'romancelandia.club',
#  'zh.pp.social',
#  'thecentralfinitecurve.com',
#  'manitu.social',
#  'birdbutt.com',
#  'mastodon.africa',
#  'webxr.social',
#  'urusai.social',
#  'swiss.social',
#  'mastodon.bayern',
#  'discordian.social',
#  'mastodon.la',
#  'furry.engineer',
#  'social.esmarconf.org',
#  'mastodon.com.py',
#  'hypno.social',
#  'www.paradiseve.com',
#  'streamers.social',
#  'ecoevo.social',
#  'recurse.social',
#  'bbq.snoot.com',
#  'mastodon-swiss.org',
#  'nluug.social',
#  'mastodon.cr',
#  'triangletoot.party',
#  'vermont.masto.host',
#  'kinkycats.org',
#  'fed.sbcloud.cc',
#  'gamingjp.org',
#  'eimtbigd-masto.techlab.uoc.edu',
#  'hachyderm.io',
#  'podcastindex.social',
#  'sonomu.club',
#  'burma.social',
#  'glauca.space',
#  'astronomy.social',
#  'federate.social',
#  'aut.social',
#  'mastodon.uno',
#  'mstdn.poyo.me',
#  'kirche.social',
#  'genealogie.social',
#  'makegayfriends.com',
#  'bear.community',
#  'gamepad.club',
#  'xarxa.cloud',
#  'gayfr.social',
#  'lepoulsdumonde.com',
#  'f-ckendehoelle.de',
#  'norden.social',
#  'gensokyo.town',
#  'brands.town',
#  'guitar.rodeo',
#  'mas.corq.co',
#  'mastodon.pnpde.social',
#  'mostodon.de',
#  'equestria.social',
#  'social.tchncs.de',
#  'toot.lv',
#  'mastodon.bergen.social',
#  'kiritan.work',
#  'owo.cafe',
#  'fedi.halcyon-is.land',
#  'gulp.cafe',
#  'shark.community',
#  'mastodonmusic.social',
#  'tweesecake.social',
#  'social.cu2d.com',
#  'colorid.es',
#  'social.liip.ch',
#  'hostux.social',
#  'pdx.sh',
#  'mastodon.ethibox.fr',
#  'pointless.chat',
#  'defcon.social',
#  'social.therestartproject.org',
#  'oomfie.city',
#  'colearn.social',
#  'sigmoid.social',
#  'mcr.wtf',
#  'nologo.social',
#  'hameln.social',
#  'neovibe.app',
#  'mastodon.social',
#  'burnthis.town',
#  'mastodon.gamedev.place',
#  'rheinneckar.social',
#  'dice.camp',
#  'mastodon.frl',
#  'framapiaf.org',
#  'toad.social',
#  'friendsofdesoto.social',
#  'yeen.exposed',
#  'mastodon.progaccess.net',
#  'bkcastle.net',
#  'occitania.social',
#  'utter.online',
#  'social.butnot.today',
#  'mstdn.tokyocameraclub.com',
#  'social.ftm.nl',
#  'aleph.land',
#  'aus.social',
#  'beach.city',
#  'mstdn.md',
#  'redpawcollective.co',
#  'aethy.com',
#  'oc.todon.fr',
#  'red.niboe.info',
#  'hoosier.social',
#  'stranger.social',
#  'bark.lgbt',
#  'mastodon.escepticos.es',
#  'esoteric.party',
#  'don.neet.co.jp',
#  'en.osm.town',
#  'leftist.network',
#  'social.horrorhub.club',
#  'beamship.mpaq.org',
#  'agilealliance.social',
#  'birdon.social',
#  'network.aipioneers.org',
#  'theatl.social',
#  'unipar.online',
#  'alpaka.social',
#  'mastodon.boston',
#  'musician.social',
#  'mastodon.nzoss.nz',
#  'mstdn.sublimer.me',
#  'senigallia.one',
#  'toot.funami.tech',
#  'irsoluciones.social',
#  'rap.social',
#  'mast.shitpostbot.com',
#  'computer-club.online',
#  'mastodon.mikmak.cc',
#  'fluffs.au',
#  'reliverse.social',
#  'mastodon.tedomum.net',
#  'socel.net',
#  'biologists.social',
#  'mastodon.holeyfox.co',
#  'social.sndevs.com',
#  'www.blimps.xyz',
#  'est.social',
#  'discuss.systems',
#  'oliphaunt.social',
#  'c.im',
#  'technodon.org',
#  'social.nofftopia.com',
#  'sauna.social',
#  'lor.sh',
#  'mastodon.landonsonline.me.uk',
#  'die-partei.social',
#  'orchard.social',
#  'social.y-gallery.net',
#  'spojnik.works',
#  'csu.coffee',
#  'blackrocks.social',
#  'sportsfeed.me',
#  'kpop.social',
#  'hessen.social',
#  'gametoots.de',
#  'oulipo.social',
#  'app.bikers.social',
#  'kinkyelephant.com',
#  'seo.chat',
#  'tooter.social',
#  'masto.kreks.nl',
#  'epicure.social',
#  'tinnies.club',
#  'sachsen-medien.social',
#  'podvibes.co',
#  'bibletalk.social',
#  'body.social',
#  'ruhr.social',
#  'mstdn.maud.io',
#  'social.thewhole.site',
#  'blimps.xyz',
#  'neurodifferent.me',
#  'muenster.im',
#  'snabelen.no',
#  'lou.lt',
#  'h5q.net',
#  'ciecuo.club',
#  'kanoa.de',
#  'mastodon.juggler.jp',
#  'mastodon.sk',
#  'nomanssky.social',
#  'mstdn.games',
#  'pravdasocial.net',
#  'foojay.social',
#  'mastodon.sdf.org',
#  'surus.keepcoding.io',
#  'ist-ur.org',
#  'lgbtqia.space',
#  'mas.to',
#  'toot.community',
#  'mofu.kemo.no',
#  'fairmove.net',
#  'warhammer.social',
#  'akademienl.social',
#  'mastodon.bv.linksjugend-solid.de',
#  'animalliberation.social',
#  'electroverse.tech',
#  'vkl.world',
#  'mstdn.party',
#  'indieapps.space',
#  'normal.style',
#  'layer8.space',
#  'mastodon.furrypaws.cc',
#  'social.ds106.us',
#  'feuerwehr.social',
#  'mastodon.de',
#  'mastodon.thenewoil.org',
#  'photodn.net',
#  'toot.re',
#  'osna.social',
#  'techtoots.com',
#  'dotgr.id',
#  'social.veraciousnetwork.com',
#  'julialang.social',
#  'mstdn.in.th',
#  'federatedfandom.net',
#  'rubber.social',
#  'mastodon.conquestuniverse.com',
#  'mcyt.cc',
#  'nyanya.net',
#  'lincolnite.net',
#  'ponies.social',
#  'mastodon.gal',
#  'weremember.social',
#  'rockcd.jp',
#  'mastodon.motcha.tech',
#  'libori.social',
#  'vis.social',
#  'edumasto.org',
#  'mastodon.tetaneutral.net',
#  'mastodon.art',
#  'bne.social',
#  'mastodon.ph',
#  'mastodonczech.cz',
#  'lehrerzimmer.social',
#  'apobangpo.space',
#  'mastodon.cisti.org',
#  'activitypub.academy',
#  'nfld.me',
#  'saronno.one',
#  'swiss-talk.net',
#  'social.schleswig-holstein.de',
#  'blips2.club',
#  'masto.bike',
#  'eupolicy.social',
#  'suma-ev.social',
#  'mathtod.online',
#  'net4sw.com',
#  'toots.nu',
#  'masto.pt',
#  'pone.social',
#  'uwu.social',
#  'homoo.social',
#  'mastodon.schule',
#  'fedisabled.social',
#  'piano.masto.host',
#  'witches.live',
#  'mastodon.nl',
#  'atheopagan.net',
#  'toot.lugbz.social',
#  'social.diva.exchange',
#  'mastodon.scot',
#  'jvm.social',
#  'toot.blue',
#  'masto.ai',
#  'leds.social',
#  'mastodon.coffee',
#  'nwb.social',
#  'prf.me',
#  'tilde.zone',
#  'quakers.social',
#  'squawk.social',
#  'aipub.social',
#  'pocketpixels.club',
#  'computerfairi.es',
#  'furry.energy',
#  'mastodon.cat',
#  'nfb.social',
#  'toot.fedispace.eu',
#  'zetaspace.org',
#  'sizecraft.social',
#  'blorbo.social',
#  'mastodon.arch-linux.cz',
#  'cville.online',
#  'mastodon.pirati.cz',
#  'mstdn.mx',
#  'systemli.social',
#  'social.techliminal.com',
#  'astrodon.social',
#  'anime.kona.moe',
#  'gardenstate.social',
#  'plushies.social',
#  'tribe.net',
#  'krigskunst.social',
#  'publicgood.social',
#  'franken.social',
#  'frogs.lgbt',
#  'aipi.social',
#  'library.love',
#  'mastodon.bachgau.social',
#  'eigadon.net',
#  'amicale.net',
#  'paktodon.asia',
#  'gaminginthe.cloud',
#  'mastodon.acerbo.me',
#  'ruhrpott.social',
#  'sauropods.win',
#  'pkm.social',
#  'retro.pizza',
#  'odakyu.app',
#  'penguicon.social',
#  'frankfurt.social',
#  'mapstodon.space',
#  'mstdn.plus',
#  'blueadair.net',
#  'triggeron.net',
#  'songbird.cloud',
#  'techforgood.social',
#  'clj.social',
#  'meerjungfrauengrotte.de',
#  'qn.krig.jp',
#  'mastodon.com.tr',
#  'milliways.social',
#  'seocommunity.social',
#  'ap.ketsuben.red',
#  'paquita.masto.host',
#  'stereodon.social',
#  'trpg-o.xyz',
#  'pnw.zone',
#  'mstdn.kemono-friends.info',
#  'f.cz',
#  'indieauthors.social',
#  'opalstack.social',
#  'woof.group',
#  'writing.exchange',
#  'medibubble.org',
#  'india.goonj.xyz',
#  'social.darc.de',
#  'tchafia.be',
#  'nrw.social',
#  'rail.chat',
#  'meow.social',
#  'open3dlab.social',
#  'geekstodon.com',
#  'planet.moe',
#  'm.einverne.info',
#  'rva.fyi',
#  'wspanialy.eu',
#  'synapse.cafe',
#  'nfdi.social',
#  'lipn.info',
#  'toot.portes-imaginaire.org',
#  'critcare.social',
#  'merveilles.town',
#  'drupal.community',
#  'bumscode.com',
#  'usstock.love',
#  'social.numerique.gouv.fr',
#  'qdon.space',
#  'mstdn.nagito.net',
#  'theblower.au',
#  'rivals.space',
#  'iztasocial.site',
#  'dariox.club',
#  'nc.social',
#  'sociale.network',
#  'blueplanet.social',
#  'www.mastodon.scot',
#  'clockwork.monster',
#  'cultofshiv.wtf',
#  'mascodon.jp',
#  'conversafiada.net',
#  'livester.net',
#  'nitiasa.com',
#  'mastodon.hosnet.fr',
#  'rss-mstdn.studiofreesia.com',
#  'ohai.social',
#  'mental.social',
#  'jit.social',
#  'meow.cloud',
#  'indg.club',
#  'fpl.social',
#  'social.sdfeu.org',
#  'globalskywatch.social',
#  'convo.casa',
#  'micc.masto.host',
#  'fosstodon.org',
#  'social.overheid.nl',
#  'super-gay.co',
#  'vt.social',
#  'mastodon.cl',
#  'social.garudalinux.org',
#  'masto.globaleas.org',
#  'merovingian.club',
#  'pokemon.mastportal.info',
#  'batchats.net',
#  'solarpunk.moe',
#  'vrcjp.hostdon.ne.jp',
#  'social.cologne',
#  'sakurajima.moe',
#  'karlsruhe.social',
#  'social.sunet.se',
#  'jidaar.net',
#  'technews.social',
#  'emacs.ch',
#  'mastodon.triggerphra.se',
#  'mastodon.tokyo',
#  'md.ilyamikcoder.com',
#  'muri.network',
#  'cloud-native.social',
#  'cosocial.ca',
#  'aoir.social',
#  'drumstodon.net',
#  'gnulinux.social',
#  'mstdn.tamag.org',
#  'jasette.facil.services',
#  'mastodon.radio',
#  'a11y.social',
#  'freie-radios.org',
#  'pebble.social',
#  'growers.social',
#  'acg.mn',
#  'ludosphere.fr',
#  'lazysocial.de',
#  'heads.social',
#  'donphan.social',
#  'toot.aquilenet.fr',
#  'transfur.social',
#  'social.sdf.org',
#  'comunidad.nvda.es',
#  'darkfriend.social',
#  'digitalpioneers.social',
#  'furries.club',
#  'toot.wales',
#  'blackrock.city',
#  'berlin.social',
#  'machteburch.social',
#  'mtgjudge.social',
#  'sciencemastodon.com',
#  'srilankans.online',
#  'rcsocial.net',
#  'mastodon.jj5fxl.net',
#  'rebel.ar',
#  'nasface.cz',
#  'pp-social.com',
#  'strangeminds.social',
#  'norcal.social',
#  'kommunismus.social',
#  'fashionsocial.host',
#  'mastodon.ee',
#  'riin.fr',
#  'mastodon.infodocs.eu',
#  'techhub.social',
#  'socialclub.nyc',
#  'techpolicy.social',
#  'gaygeek.social',
#  'veganism.social',
#  'swecyb.com',
#  'mastodon.green',
#  'vocalodon.net',
#  'social.spejset.org',
#  'livellosegreto.it',
#  'lounge.town',
#  'sparrow.cs.uni-magdeburg.de',
#  'mstdn.myifn.de',
#  'graeber.social',
#  'front-end.social',
#  'mastodon.tn',
#  'kind.social',
#  'earthstream.social',
#  'cupoftea.social',
#  'zirk.us',
#  'esglife.social',
#  'unbound.social',
#  'klog.tw',
#  'netsphere.one',
#  'dftba.club',
#  'iwatedon.net',
#  'mona.do',
#  'recht.social',
#  'kopiti.am',
#  'selfhosted.cafe',
#  'mastodon.cloudsecurityofficehours.com',
#  'mastodon.catgirl.cloud',
#  'mastodon.hams.social',
#  'forum-lucifer.com',
#  'freie-re.de',
#  'fandomonium.space',
#  'lsbt.me',
#  'trans.house',
#  'argon.city',
#  'mastodon.twictee.org',
#  'cubhub.social',
#  'nashtodon.com',
#  'elizur.me',
#  'ieji.de',
#  'pravda.me',
#  'social.mikutter.hachune.net',
#  'sueden.social',
#  'snailedit.social',
#  'genomic.social',
#  'pony.social',
#  'furs.social',
#  ...}

# %%
# "Available" data: the entire Mastodon network (that we know of).
## File to dict
available_local_posts = {}
with INSTANCE_DATA_PATH.open("r") as file:
    for line in file:
        line_dict = loads(line)
        # if line_dict["instance"] not in crawled_instances:
        #     continue
        if "nodeinfo" not in line_dict or line_dict["nodeinfo"] is None:
            continue
        nodeinfo = line_dict["nodeinfo"]
        if "usage" not in nodeinfo or nodeinfo["usage"] is None:
            continue
        usage = nodeinfo["usage"]
        if "localPosts" not in usage or usage["localPosts"] is None:
            continue
        available_local_posts[line_dict["instance"]] = usage["localPosts"]
available_local_posts
# Out:
# {'0rb.it': 860,
#  '0ab.uk': 14,
#  '0v0.ch': 46,
#  '0x4655.co.uk': 0,
#  '0xee.io': 199,
#  '0x50.ch': 2,
#  '10mb.social': 475,
#  '100terres.social': 4,
#  '0371.uk': 152,
#  '0x3c.pl': 2340,
#  '1210.nl': 958,
#  '103.social': 252,
#  '10211104.fedicity.net': 26529,
#  '13bells.com': 9489,
#  '1435.es': 39,
#  '1745.info': 316,
#  '15-15-15.social': 392,
#  '19marbles.org': 4065,
#  '1password.social': 913,
#  '184.im': 8,
#  '1234.as': 767493,
#  '23.illuminati.org': 1569,
#  '1uca.com': 219815,
#  '285936586.masto.host': 16671,
#  '27origin.com': 231,
#  '0taku.xyz': 705,
#  '2pxnl.de': 1484,
#  '280562.com': 115,
#  '2c.taoetc.org': 1501,
#  '333thats33s.cc': 581,
#  '3615.computer': 9511,
#  '30d.org': 2,
#  '3rdstone.cc': 3178,
#  '3dp.chat': 7113,
#  '3zi.ru': 135897,
#  '3rdwall.net': 36,
#  '386898.xyz': 45,
#  '366.koyomi.online': 2789,
#  '39sounds.net': 2034,
#  '41020.social': 7032,
#  '338338.xyz': 981,
#  '433.world': 12315,
#  '4four.org': 97,
#  '404.inexist.club': 22468,
#  '430022.xyz': 12,
#  '4458644.xyz': 24,
#  '4bear.com': 101372,
#  '503junk.house': 16507,
#  '60jj.masto.host': 576,
#  '5lb.co': 52,
#  '5280.city': 393,
#  '60228.dev': 8981,
#  '6502.social': 16,
#  '4liberty.one': 241,
#  '6510.nu': 889,
#  '666.glitchwit.ch': 14006,
#  '7rg.de': 40,
#  '6t.vc': 222,
#  '80chars.io': 1,
#  '7snowrin.net': 1358,
#  '802.3ether.net': 8043,
#  '8bit.red': 1198,
#  '8bit.social': 352,
#  '7144.party': 25562,
#  '56kbits.cloud': 333,
#  '438punk.house': 29397,
#  'a.dags.dk': 6,
#  'a.brody.zone': 28,
#  '907.life': 197,
#  '9kb.me': 215080,
#  '1132don.com': 1178,
#  'a.katgirl.club': 1860,
#  '0x40.au': 4,
#  'a.xerimorph.net': 71,
#  'a11y.info': 12366,
#  'a17k.social': 80,
#  'a.gawlinski.com': 225,
#  'aachen.social': 7734,
#  'a2mi.social': 209145,
#  'aana.site': 42998,
#  'a1computers.social': 20,
#  'a11y.social': 2014,
#  'abc.mika.xyz': 29,
#  'abend.social': 2286,
#  'abdl.link': 299171,
#  'abitmu.ch': 157,
#  'abando.social': 26,
#  'abraum.social': 437,
#  'abraham.su': 462,
#  'aberrantwinds.bond': 852,
#  'abraham.social': 15,
#  'absurd.social': 6,
#  '25ji.nightcord.de': 2,
#  'abyssdomain.expert': 1307,
#  'abolish.social': 20862,
#  'academe.social': 168,
#  'academia.pub': 2,
#  'academic.social': 9,
#  'academiccloud.social': 2729,
#  'abpe.org': 4289,
#  'accessibility.social': 107,
#  'accessnow.social': 21,
#  'accioly.social': 248,
#  'acgn.ca': 0,
#  'achrilock.social': 2416,
#  'acc4e.com': 1943,
#  'abyss.fun': 577355,
#  'a.tripulse.link': 1115,
#  'acg.ngo': 0,
#  'acra.network': 4,
#  'acg.mn': 214957,
#  'about.to.be.nota.live': 19,
#  'achi.masto.host': 72914,
#  'activity.kammeyer.me': 57,
#  'activitypub.academy': 67,
#  'academictalk.org': 112,
#  'activitypup.de': 1008,
#  'activitypub.garmy.jp': 6989,
#  'adforward.org': 702,
#  'adhd.energy': 1057,
#  'adhd.recipes': 2,
#  'abypom.work': 71440,
#  'adtech.life': 40,
#  'adulthood.lol': 266,
#  'adventurousbeastie.eu': 2133,
#  'adventures.social': 184,
#  'adastra234.info': 71959,
#  'adxm.social': 3,
#  'adtech.land': 53,
#  'advent.social': 898,
#  'aether.run': 13,
#  'afcolegiado.app': 9307,
#  'aethernet.social': 326,
#  'aethy.com': 818099,
#  'afnsocial.co': 0,
#  'afop.social': 23,
#  'aeternam.hostdon.ne.jp': 13408,
#  'afk.social': 30,
#  'agencycollective.masto.host': 21,
#  'afterspace.rocks': 13472,
#  'agilodon.social': 2315,
#  'afternoonauthor.online': 12,
#  'agora-thinktanks.social': 222,
#  'agilealliance.social': 6425,
#  'afn.game-host.mydns.jp': 6,
#  'activitypub.owenryan.us': 8,
#  'ahlers.xyz': 146,
#  'agnesta.ch': 42,
#  'agora.ilot.io': 335,
#  'ailbhean.co-shaoghal.net': 7959,
#  'aipi.social': 22859,
#  'aircrew.rocks': 3840,
#  'airpollution.science': 1576,
#  'air11.social': 327,
#  'aipub.social': 5467,
#  'aisler.social': 91,
#  'aitor-sama.es': 190,
#  'ajin.la': 42294,
#  'airwaves.social': 598214,
#  'ajtaci.club': 158,
#  'ajm-central.duckdns.org': 142294,
#  'adney.land': 199,
#  'akademienl.social': 34279,
#  'akiba.party': 2916,
#  'akiba.social': 3077,
#  'akarisu.eu': 0,
#  'akasa.red': 391,
#  'akirin.hostdon.ne.jp': 949,
#  'akuanduba.masto.host': 348,
#  'ala.masto.host': 63,
#  'alaskan.social': 25246,
#  'albaruthenica.masto.host': 198,
#  'albanian.social': 9,
#  'aldr.social': 1343,
#  'alcove.website': 3173,
#  'alentours.cc': 907,
#  'aleph.land': 215935,
#  'alexcrawford.co.uk': 10,
#  'alfajet.masto.host': 3188,
#  'algebra.chat': 49,
#  'algufr.com': 101,
#  'alice.haconiwa.hostdon.ne.jp': 634,
#  'alice486.com': 174,
#  'alittle.social': 84,
#  'allagar.masto.host': 1314,
#  'aliensoup.social': 56,
#  'alinke.com': 2487,
#  'allamaraine.io': 1490,
#  'alive.bar': 4572467,
#  'alleysmith.family': 794,
#  'allies.social': 820,
#  'allison.social': 351,
#  'allpeep.social': 223,
#  'allpro.social': 83867,
#  'alliec.at': 27,
#  'allthingstech.social': 34962,
#  'almajlis.me': 122,
#  'alltomorrows.party': 2512,
#  'alpaka.garden': 4465,
#  'alpaka.social': 9208,
#  'alphabetica.masto.host': 3468,
#  'aloha-pink.monster': 17,
#  'alpaca.gold': 7096,
#  'alpines.club': 1315,
#  'allships.run': 237217,
#  'alteholz.social': 5199,
#  'alpherg.fedicity.net': 137,
#  '1m2lab.anvil.top': 991,
#  'alva.host': 7,
#  'alwayssleeping.com': 276,
#  'alwyzon.social': 4,
#  'amastodon.uk': 4683,
#  'alt.lawndale.space': 3316,
#  'amateurfunk.social': 21,
#  'ambercons.masto.host': 148,
#  'amberpapilio.masto.host': 388,
#  'amaurot.city': 10352,
#  'altermann.masto.host': 2653,
#  'ambition.rip': 414,
#  'america.social': 152,
#  'amicale.net': 458694,
#  'amiga.team': 137,
#  'amigosblasterradio.masto.host': 62,
#  'amok.recoil.org': 807,
#  'amigos.family': 289,
#  'amour.social': 0,
#  'amphora.social': 876,
#  'amst.io': 154,
#  'amynews.social': 676,
#  'an.errant.cloud': 1813,
#  'amormor.art': 3551,
#  'alsohere.net': 114,
#  'anakmanis.com': 3659,
#  'amungus.duckdns.org': 0,
#  'anandamide.net': 1470,
#  'anancus.fr': 596,
#  'an.eldritch.gift': 1365,
#  'anarchism.space': 254312,
#  'anarres.family': 30727,
#  'anarshy.social': 500,
#  'andersen.social': 863,
#  'alonecomplex.xyz': 15797,
#  'andrews.me': 217,
#  'androiddev.social': 76046,
#  'andrew.xyz': 17,
#  'androidmanife.st': 1,
#  'andyetzler.social': 5,
#  'anasodon.com': 1670,
#  'andypiper.social': 5,
#  'angelou.club': 13,
#  'angrytoday.com': 11395,
#  'ani.work': 110267,
#  'anikeen.social': 3,
#  'angrydome.au': 445,
#  'animal.business': 12003,
#  'animal-crossing.mastportal.info': 120377,
#  'animalliberation.social': 4896,
#  'animeomake.com': 16,
#  'anml.io': 119,
#  'andalucia.social': 3244,
#  'anomaly.center': 3,
#  'anosdesiertos.love': 160,
#  'ansible.jshwlkr.info': 229,
#  'ansico.dk': 1652,
#  'antabaka.me': 10092,
#  'ansiktsburk.se': 52,
#  'anothersuper.social': 85,
#  'anticapitalist.party': 317013,
#  'anticapitalistcatgirl.club': 2302,
#  'anticapitalista.it': 278,
#  'anthem.shadowlan.net': 0,
#  'antisleepdevice.de': 11,
#  'antiquated.systems': 51,
#  'antisocial.existentialdread.com': 168,
#  'anti-social.online': 4895,
#  'antisocial.notyour.tech': 598,
#  'antisocial.thebubble.noho.st': 63,
#  'anubis.social': 8801,
#  'antisocial.ly': 2233,
#  'anus-jokes.social': 2,
#  'anvil.social': 1377,
#  'any.dev': 543,
#  'anywise.net': 307,
#  'aoir.social': 14763,
#  'aoikaze.social': 145,
#  'ap.alexjanka.com': 0,
#  'annex.coffee-break.cc': 6217,
#  'ap.pachy.social': 0,
#  'ap.ketsuben.red': 153133,
#  'apkallu.us': 64,
#  'apocalypse.net': 65,
#  'antisocial.science': 31158,
#  'apobangpo.space': 99195,
#  'apotheke.social': 26749,
#  'app.bikers.social': 7767,
#  'app.ediscovery.social': 0,
#  'apple2.org.za': 2,
#  'appellate.ninja': 5,
#  'appellate.social': 1705,
#  'appsignal.social': 140,
#  'animalesenfu.ga': 2921,
#  'aquariumofyourbrain.masto.host': 197,
#  'apricot.social': 1672,
#  'arabi.gay': 3446,
#  'arachnibot.masto.host': 0,
#  'an.exchange': 1639,
#  'anarchy.center': 8902,
#  'arasaka.vip': 435,
#  'arasaka.biz': 0,
#  'archaeo.social': 42547,
#  'archaeology.social': 1395,
#  'arbitrarymusings.com': 2,
#  'architektur.social': 146,
#  'aquatan.net': 26222,
#  'arcticwind.social': 0,
#  'ard.social': 18772,
#  'area51.social': 6136,
#  'arezzo.one': 16,
#  'arff.archandle.net': 2033,
#  'arewe.social': 677,
#  'argon.city': 10232,
#  'arielfinn.social': 2293,
#  'arkm.social': 438,
#  'arihi.me': 7,
#  'arnesocial.de': 1,
#  'arrifana.org': 466,
#  'arrrgh.online': 568,
#  'artatomic.social': 2440,
#  'arthropod.social': 1504,
#  'artindekker.com': 3,
#  'arsenalfc.social': 30558,
#  'artoot.xyz': 11608,
#  'artsandculture.social': 1187,
#  'arktos.social': 3450,
#  'artistalley.space': 610,
#  'arxiv.social': 62,
#  'artsocial.boston': 593,
#  'arvr.social': 13705,
#  'as9136.social': 13,
#  'asbestosden.org': 413,
#  'aschaffenburg.social': 1360,
#  'ashka.me': 2250,
#  'asciisnowman.yachts': 195,
#  'ashlande.rs': 302,
#  'ashworth.io': 56,
#  'asciifortrouble.com': 1255,
#  'asocial.dk': 31,
#  'asentientbot.ca': 63,
#  'asocial.social': 23,
#  'aspa.masto.host': 1117,
#  'assemblag.es': 48009,
#  'artsio.com': 20238,
#  'asso.lgbt': 345,
#  'assonance.org': 9,
#  'asstodon.social': 10478,
#  'astral.camp': 8003,
#  'assortedflotsam.com': 281979,
#  'astrel.la': 50,
#  'astrian.social': 4093,
#  'astronomy.city': 8658,
#  'astronomy.social': 6193,
#  'astrodon.social': 129458,
#  'astroposting.de': 1287,
#  'astrotwitter.masto.host': 3168,
#  'astrum.social': 25,
#  'async.social': 347,
#  'astrosocial.space': 6,
#  'aseriesoftubes.social': 300,
#  'atheopagan.net': 662,
#  'atdt.cc': 139,
#  'atilla.im': 36,
#  'atmasto.com': 1195,
#  'atergens.com': 757,
#  'atsuchan.page': 26482,
#  'asylum.nz': 1692,
#  'astro.clinic': 64,
#  'astrolaboratory.club': 700,
#  'atta.ch.to': 598,
#  'attractive.space': 10582,
#  'atx.social': 460,
#  'aucubin.social': 0,
#  'atx.pub': 4910,
#  'audax.social': 16,
#  'audio-video.tech': 350,
#  'augsburg.social': 35414,
#  'august-don.site': 1062,
#  'auralis.space': 112,
#  'aurorign.social': 247,
#  'atis.social': 846,
#  'audiophile-mastodon.com': 20417,
#  'aus.social': 2132360,
#  'aut.social': 14307,
#  'austintexas.social': 25312,
#  'ausmed.social': 203,
#  'atsudon.fedicity.net': 3762,
#  'autistics.life': 43978,
#  'autisticnomad.social': 1155,
#  'autonomous.zone': 15509,
#  'auxim.social': 12,
#  'avali.one': 126,
#  'autobots.run': 52,
#  'avatastic.uk': 2958,
#  'avantwhatever.org': 2935,
#  'av8r.ca': 192,
#  'avgeek.social': 4795,
#  'avision-it.social': 2834,
#  'awawa.meo.ws': 381,
#  'awau.social': 433,
#  'awai.hostdon.ne.jp': 165,
#  'awaymessage.club': 8845,
#  'awjeez.help': 1720,
#  'awoo.fi': 13,
#  'awoo.studio': 947,
#  'awp.news': 8571,
#  'awesomein.space': 5,
#  'awoo.chat': 620,
#  'awscommunity.social': 212627,
#  'awoo.stormcrest.org': 103,
#  'awoo.town': 170,
#  'axiomeval.social': 68,
#  'awwter.online': 59201,
#  'ayom.media': 22022,
#  'azemet.space': 69,
#  'awoo.space': 647985,
#  'az.social': 2810,
#  'awesome.garden': 3422,
#  'b0.ax': 330,
#  'awes.one': 196,
#  'babicz.social': 69,
#  'bachmann.social': 178,
#  'backend-staging.newsmast.org': 4681,
#  'backend.newsmast.org': 18787,
#  'babblebox.net': 700,
#  'babka.social': 157431,
#  'babyfurs.social': 6413,
#  'b612.icu': 72181,
#  'backpacklife.social': 438,
#  'backs.day': 444,
#  'autistic.social': 59,
#  'bad-radio.social': 3139,
#  'bagarrosphere.fr': 21554,
#  'bahn.social': 64016,
#  'baguette-it.social': 137,
#  'baka.social': 1342,
#  'backyard.cloud': 14989,
#  'babelfish.tombies.eu': 7000,
#  'bakunet.me': 16,
#  'ballhaus.community': 444,
#  'badgay.net': 6346,
#  'baltic.social': 44,
#  'bambuswald.social': 11276,
#  'bakedbean.xyz': 102923,
#  'bangdream.space': 102764,
#  'banter.danny.page': 248,
#  'banjo.town': 3311,
#  'bantu.social': 147306,
#  'bangdream.tokyo': 116,
#  'barcamp.social': 13208,
#  'bardown.space': 4863,
#  'bark.lgbt': 157799,
#  'barelysocial.org': 1253,
#  'baram.me': 3327,
#  'barca.dix.asia': 107289,
#  'barkoczy.social': 213,
#  'barkclub.xyz': 1660,
#  'barnes.social': 1159,
#  'barrowof.gay': 1326,
#  'barks.me': 55,
#  'bananachips.club': 90503,
#  'base.lc': 2675,
#  'bas.tn': 14,
#  'basilisk.gallery': 303,
#  'baraag.net': 11312784,
#  'bath.social': 1724,
#  'battle7.net': 0,
#  'batchats.net': 1046,
#  'baudigital.social': 636,
#  'bauphysik.social': 150,
#  'bayern-online.news': 2186,
#  'baum.social': 229,
#  'bayes.club': 12798,
#  'bb5.social': 5,
#  'bbq.snoot.com': 82658,
#  'bbiz.io': 995,
#  'bat.chat': 0,
#  'bbbdn.jp': 241615,
#  'bcom.moe': 784,
#  'bcostodon.lol': 615,
#  'bbq.golf': 372,
#  'be58.co': 2,
#  'be-lieve.hostdon.ne.jp': 100257,
#  'beach.city': 268692,
#  'beam.ta.rdis.dev': 937,
#  'beamship.mpaq.org': 4309,
#  'bearologics.social': 1364,
#  'beatles.chat': 42,
#  'bears.town': 16882,
#  'beatles.social': 136,
#  'beaulieu.social': 7,
#  'beausimensen.feder8.io': 92,
#  'beautifullosers.org': 2072,
#  'bad.posts.gallery': 88,
#  'beef.moe': 900,
#  'becker.pizza': 4,
#  'beefus.camp': 13,
#  'beepboop.one': 65200,
#  'beergeek.social': 174,
#  'beekeeping.ninja': 28319,
#  'basstdn.jp': 212,
#  'beige.party': 723959,
#  'beery.beer': 76,
#  'bball.city': 341,
#  'bell.bz': 4483,
#  'beeslink.com': 424,
#  'bend.town': 615,
#  'bencarneiro.com': 135,
#  'benedikts.social': 2270,
#  'bencollier.uk': 33,
#  'benehomini.social': 734,
#  'benten.ch': 25,
#  'beltaine.day': 367,
#  'benward.social': 316,
#  'bellow.el.drit.ch': 436,
#  'benz.masto.host': 99,
#  'bensie.social': 38,
#  'beo.social': 468,
#  'benz.social': 6,
#  'bequeme-couch.de': 232,
#  'beppo.online': 17761,
#  'benzo.fans': 5567,
#  'bergamot.social': 579,
#  'beratna.net': 25726,
#  'benjamin.social': 0,
#  'berlin.social': 277020,
#  'berserker.town': 64521,
#  'bertha.social': 18645,
#  'bern.social': 277,
#  'berlin-berlin.de': 3467,
#  'bertshouse.social': 17128,
#  'besties.com': 18,
#  'best-friends.chat': 12189862,
#  'betterconversations.online': 215,
#  'better.boston': 91175,
#  'beutl.space': 22,
#  'beta.tapbots.social': 140,
#  'beyond.forum': 43,
#  'beyondwatts.social': 3113,
#  'beyondgender.social': 165,
#  'bewegung.social': 7918,
#  'betweenthelions.link': 15335,
#  'beta.qdon.space': 520711,
#  'bfs.llc': 39,
#  'bfd.so': 187,
#  'bhre.social': 2573,
#  'beyonoyasashiisekai.hostdon.ne.jp': 321,
#  'bhis.social': 0,
#  'bibletalk.social': 570,
#  'biblioverse.online': 5945,
#  'biddul.ph': 364,
#  'bigballchunkyverse.online': 9,
#  'bifrost.berzerk.pl': 253,
#  'biggs.social': 51,
#  'bien-etre.social': 1425,
#  'bigshoulders.city': 26292,
#  'bihar.social': 588,
#  'bikepacking.social': 51,
#  'bikesare.cool': 255,
#  'bigchat.social': 4,
#  'bildung.social': 289302,
#  'bikeshed.vibber.net': 7238,
#  'bimbo.social': 90,
#  'billsmafia.social': 1373,
#  'binarytales.social': 12,
#  'binarystar.social': 0,
#  'billys.mom': 664,
#  'biologists.social': 43523,
#  'biplus.social': 2179,
#  'birb.casa': 180,
#  'birb.site': 49580,
#  'bird.rodeo': 2310,
#  'birdbox.party': 141,
#  'birdinter.net': 1389,
#  'binky.fish': 136,
#  'birdon.social': 9738,
#  'birds.town': 38217,
#  'birdhouse.social': 24,
#  'birdbutt.com': 11878,
#  'birds.social': 227,
#  'bisset.me.uk': 15,
#  'bitfudge.com': 910,
#  'bits.social': 175,
#  'biscuit.town': 212804,
#  'biu.im': 23,
#  'bitsandpixels.dev': 167,
#  'bitwoods.duckdns.org': 102,
#  'bizarre.social': 6,
#  'bjgp.social': 272,
#  'bjd.social': 65,
#  'bla.daanberg.net': 3541,
#  'bkcastle.net': 4107,
#  'blabber.lu-rp.net': 16141,
#  'blabber.rocks': 4016,
#  'blaahaj.com': 2261,
#  'blackqueer.life': 6305,
#  'blackrock.city': 1624,
#  'blackrocks.social': 519,
#  'blackshuck.net': 1094,
#  'blacktwitter.io': 78134,
#  'blacksun.social': 16617,
#  'blahaj.ovh': 18,
#  'blahaj.social': 35451,
#  'blahaj.finch.ink': 338,
#  'blan.cc': 1017,
#  'blasius.club': 271,
#  'blasmusik.social': 268,
#  'blat.at': 2847,
#  'blasto.cbc.lol': 10,
#  'blazinggophers.com': 261,
#  'blauerhimmel.eu': 184,
#  'blieb.net': 210,
#  'blimps.xyz': 190563,
#  'blips2.club': 915,
#  'bitbang.social': 132516,
#  'blob.coffee': 2,
#  'blockriot.com': 10161,
#  'blahaj.zone': 162694,
#  'blewsky.social': 2509,
#  'blockfowl.com': 124,
#  'blobfox.coffee': 17920,
#  'bloade.social': 0,
#  'balkan.fedive.rs': 4599,
#  'blog.fami.ga': 509,
#  'blog.infraspread.net': 1,
#  'blog.mbe.tv': 716,
#  'blog.mapblog.xyz': 0,
#  'blog.stegemann.de': 480,
#  'blog.shiton.xyz': 1434,
#  'blog.troch.org': 20,
#  'blogator.com': 21,
#  'blogi.social': 1234,
#  'blorbo.social': 196454,
#  'bloor.tw': 4347,
#  'blue-sky.world': 4330,
#  'bloom.surf': 343,
#  'blub.social': 6,
#  'blop.social': 4372,
#  'blueadair.net': 6323,
#  'blooming-land.icu': 34386,
#  'blubrry.chat': 72,
#  'bluebell.social': 1184,
#  'blue.yuv.pink': 46,
#  'bluenoser.me': 4296,
#  'bluelupine.social': 5527,
#  'blueplanet.social': 7117,
#  'bluechakra.cloud': 1490,
#  'bluefox.social': 326,
#  'blumenwie.se': 1742,
#  'blue-write.com': 1005,
#  'bluetoot.hardill.me.uk': 1743,
#  'bmbl.fun': 0,
#  'blueand.red': 109,
#  'bnamed.social': 32,
#  'bnnuy.space': 4523,
#  'bnuy.space': 1145,
#  'bobbinsrobots.com': 304,
#  'blueviolet.monster': 2596,
#  'bnuy.zone': 157,
#  'bobs.social': 1,
#  'bms.social': 881,
#  'bne.social': 85014,
#  'blumpus.com': 190,
#  'boeck.social': 4,
#  'body.social': 6404,
#  'boing.world': 13828,
#  'boitam.eu': 76862,
#  'bokormebolet.masto.host': 1616,
#  'bol.social': 37,
#  'bog.social': 34,
#  'bocchi.yamako-ya.com': 4089,
#  'boilingcong.ee': 2724,
#  'boles.xyz': 12225,
#  'boisterous.community': 309,
#  'boldcity.social': 1777,
#  'bologna.one': 7185,
#  'bondsdogs.com': 981,
#  'bolha.us': 58800,
#  'boner.camp': 424,
#  'bondine.social': 153,
#  'bols.games': 5821,
#  'bonga.nu': 464,
#  'bonk.expert': 102,
#  'bonequest.net': 9328,
#  'bonn.social': 246963,
#  'bookclub.masto.host': 201,
#  'bookish.community': 631,
#  'booktoot.club': 9127,
#  'booktoot.social': 3761,
#  'bookstodon.thestorygraph.com': 3261,
#  'bookstodon.com': 23381,
#  'bookstodon.net': 40,
#  'bookwor.ms': 312077,
#  'boop.city': 2642,
#  'boopsnoot.de': 706,
#  'boop.network': 65,
#  'boosterfive.com': 1446,
#  'boothtml.social': 7,
#  'boothcomputing.social': 4821,
#  'bopjoy.cafe': 3,
#  'borahae.love': 6136,
#  'bora.army': 6654,
#  'boskovice.social': 2032,
#  'bostonmusic.online': 2648,
#  'bostonglobe.social': 0,
#  'bot.ave5.dev': 2494,
#  'borderland.tokyo': 111,
#  'bot.swiss.social': 11736,
#  'botany.social': 2846,
#  'borderline.city': 11,
#  'bots.automatica.dev': 5311,
#  'botta.social': 50,
#  'botsin.space': 26044089,
#  'bots.krohsnest.com': 902906,
#  'bots.defencegeeks.net': 72106,
#  'bots.fedi.cr': 37431,
#  'boteden.com': 31380,
#  'bouma.social': 485,
#  'boumi.me': 236,
#  'bostonsocial.online': 2531,
#  'bowlofpetunias.net': 28,
#  'botwerks.social': 360,
#  'bqri.us': 13,
#  'brainstew.co': 48,
#  'boymoder.biz': 9843,
#  'brandenburg.social': 11656,
#  'brands.town': 17048,
#  'brandontemplar.social': 18,
#  'brain404.com': 230,
#  'breadandroses.cloud': 173,
#  'brbn.social': 437,
#  'breeze.town': 33,
#  'breakpoint.cafe': 2954,
#  'brettspiel.space': 47357,
#  'breizh.social': 252,
#  'bremen.digital': 0,
#  'brgrealty.ap.social': 3,
#  'brians.town': 15,
#  'brainworms.io': 1014,
#  'bridport.social': 99,
#  'brignell.co': 1226,
#  'briefly.eric.pe': 30,
#  'brinjal.org': 6117,
#  'bright.rosy-colored.space': 213,
#  'boys-love.xyz': 117,
#  'brisingr.uk': 36,
#  'brocks.social': 711,
#  'bris.to': 0,
#  'broken.graphics': 8240,
#  'brokkoli.social': 201,
#  'brighteon.social': 2774356,
#  'brotkru.me': 3181,
#  'bronyfurry.com': 47,
#  'bruder.space': 2110,
#  'brunch.zone': 22,
#  'brunty.social': 3112,
#  'broadcast.looplab.net': 3,
#  'brontosin.space': 8093,
#  'brso.social': 3,
#  'bscabl.ddns.net': 557,
#  'bumscode.com': 2088,
#  'bts.chat': 9,
#  'bs-x.org': 185,
#  'bucher.naturesmeatcandy.org': 53,
#  'bullcity.space': 1635,
#  'bundyo.com': 4714,
#  'bun.social': 13,
#  'bunny.cloud': 421,
#  'bunt.social': 38302,
#  'bunni.social': 1955,
#  'bunny.blue': 3514,
#  'bulles.social': 720,
#  'bunny.social': 1452,
#  'burg.art': 0,
#  'burningnebula.net': 1144,
#  'burma.social': 5595,
#  'bussmann.social': 533,
#  'buttplug.engineer': 439,
#  'burnout.cafe': 888,
#  'butts.team': 31322,
#  'buttplug.zone': 3499,
#  'burnthis.town': 17302,
#  'bvb.social': 226,
#  'buttsex.restaurant': 303,
#  'bwa.social': 50,
#  'bvp.me': 2206,
#  'bytearray.eu': 445,
#  'byteheaven.net': 2310,
#  'bygg.land': 117,
#  'bynight.cafe': 149,
#  'bytepark.social': 3623,
#  'bytetower.social': 10251,
#  'bzh.social': 4925,
#  'c.im': 2146917,
#  'byteunion.com': 53,
#  'c18.masto.host': 26019,
#  'c3d2.social': 9999,
#  'c64.social': 2984,
#  'brioco.social': 1130,
#  'cadexos.com': 3,
#  'cackl.io': 2375,
#  'c4.social': 1816,
#  'c7.io': 4634,
#  'cailincat.cloud': 5061,
#  'calamity.masto.host': 589,
#  'calamity.world': 1798,
#  'cafe.mantyke.icu': 364,
#  'calc-dev1.simkey.net': 9,
#  'c.ryanccn.dev': 136,
#  'calckey.anzui.dev': 597,
#  'calckey.club': 661,
#  'caleida.com': 258,
#  'calculate.social': 9127,
#  'calckey.warrows.fr': 445,
#  'cal.gaooo.world': 4446,
#  'calckey.world': 24118,
#  'caluser.social': 3,
#  'calckey.resonite.co.uk': 26,
#  'camp.smolnet.org': 34357,
#  'campdarling.com': 22,
#  'calc.panta.systems': 10621,
#  'campduffel.social': 2314,
#  'calckey.cinatrin.pro': 16,
#  'canada.masto.host': 38712,
#  'campdon.jp': 21,
#  'cal.vino.blue': 50619,
#  'canarygateway.com': 10100,
#  'candycorn.club': 291,
#  'canzan.chat': 0,
#  'canary.fedibird.com': 7,
#  'cansoccer.social': 552,
#  'cantos.social': 6957,
#  'carabunga.net': 29,
#  'careers.lesbianblockbuster.com': 222,
#  'capcom.social': 4,
#  'carelesswhisper.nl': 918,
#  'cariad.social': 260,
#  'carhenge.club': 7585,
#  'carfree.city': 14245,
#  'carl.fish': 692,
#  'calckeymusic.social': 1507,
#  'carman.social': 6,
#  'cartbefore.horse': 31,
#  'carpdiem.online': 435,
#  'cas.social': 396,
#  'cartersville.social': 600,
#  'cascadia.games': 125,
#  'cascarilla.social': 3958,
#  'calc.bal.ovh': 51018,
#  'castilla.social': 293,
#  'catcatnya.com': 179850,
#  'calc.04.si': 36076,
#  'catharsis.cafe': 4201,
#  'cascadia.fun': 8,
#  'cathrow.social': 68,
#  'caluettefamily.com': 1196,
#  'catodon.social': 16535,
#  'catskill.social': 1,
#  'cau.se': 0,
#  'cats.mastodon.musk.sucks': 0,
#  'cauchy.ap.social': 3,
#  'catboomer.net': 213,
#  'cavalina.net': 1146,
#  'catgirl.works': 14781,
#  'cbctech.app': 0,
#  'cbulock.social': 5,
#  'cc.chat': 143,
#  'cc.pwntoney.com': 436,
#  'cc2.at': 20,
#  'catswords.social': 22392,
#  'ccccoding.club': 11,
#  'cccwi.social': 141,
#  'cc.bi': 27,
#  'ccrvb.com': 503,
#  'cdrum.social': 634,
#  'ceejayoz.io': 641,
#  'cdt.social': 10,
#  'celt.social': 507,
#  'ceilidh.online': 2423,
#  'celsius.letemps.social': 483,
#  'censurion.tk': 0,
#  'cerb.social': 38,
#  'cerb.monster': 19,
#  'centertown.fun': 1447,
#  'celtic.blue': 433,
#  'cgtest.masto.host': 1,
#  'chablis.social': 143,
#  'cats.city': 6023,
#  'cesspool.city': 231,
#  'chabant.social': 2302,
#  'champis.social': 0,
#  'catgirls.cafe': 5,
#  'calckey.art': 4518,
#  'chain.closetoya.com': 26,
#  'chalk.moe': 14324,
#  'chaos.futbol': 1205,
#  'chaos-gp.social': 114,
#  'chaos.tips': 1901,
#  'chaos.social': 5769039,
#  'chan.thebeans.zip': 392,
#  'chaosfurs.social': 5787,
#  'chaotic.social': 12500,
#  'characters.cafe': 141,
#  'chaosfem.tw': 161758,
#  'changelog.social': 1901,
#  'chaosphere.hostdon.jp': 1828207,
#  'charr.engineer': 592,
#  'chat.rittmanchat.org': 254,
#  'chat.radialbog9.com': 3,
#  'chat.vr3d.social': 88,
#  'chat.qca.net': 15,
#  'chatch.at': 42,
#  'channels.im': 277315,
#  'chat.trueffzido.de': 1933,
#  'chatter.quux.world': 1197,
#  'chattergrid.com': 58,
#  'chattingdarkly.org': 1786,
#  'chatsubo.bar': 291,
#  'checked.social': 0,
#  'chatty.littleblue.men': 0,
#  'chelseafc.social': 45,
#  'cheekibreeki.express': 865,
#  'chemnitz.network': 993,
#  'cheddarcrackers.club': 3357,
#  'cheeseburger.social': 8382,
#  'chat.noelle.codes': 28853,
#  'charcolle.art': 4405,
#  'chilemasto.casa': 30174,
#  'childcare.hostdon.ne.jp': 10253,
#  'chat.zlatiah-no.one': 1718,
#  'chillout.chat': 110195,
#  'chin-co-ne.co': 102912,
#  'chitter.xyz': 1168098,
#  'chirpnest.net': 42,
#  'chirp.enworld.org': 34074,
#  'catgirl.fr': 691,
#  'choam.social': 6,
#  'cho.yukiya.me': 5369,
#  'calc.menac.at': 34602,
#  'chittr.sbargv2.com': 837,
#  'chriswood.social': 69,
#  'chromium.social': 328,
#  'chswx.social': 1971,
#  'chtn.uk': 84,
#  'ciberlandia.pt': 40854,
#  'chud.space': 28,
#  'ciecuo.club': 5760,
#  'cincy.social': 301,
#  'cijber.social': 11272,
#  'cinnamond.social': 288,
#  'circleofamber.com': 11,
#  'circumstances.run': 38396,
#  'circus.town': 94868,
#  'cirrus.zinzolin.fr': 79,
#  'citydweller.social': 1383,
#  'cityofchicago.live': 15313,
#  'ciurdarea.nu': 98,
#  'cirno9.mynetgear.com': 316,
#  'citroen2cv.net': 6,
#  'chrosy.net': 152,
#  'ck.comfy.blue': 1268,
#  'claes.social': 29,
#  'ck.katzen.cafe': 5652,
#  'clacks.link': 35015,
#  'clar.ke': 878,
#  'clacks.eu': 60,
#  'claris.cf': 8789,
#  'classicalmusic.social': 3420,
#  'clacks.social': 29,
#  'claristdon.link': 23378,
#  'chasmcity.net': 2688,
#  'click.ba.it': 7519,
#  'cleverdevil.club': 1556,
#  'ck.villisek.fr': 289,
#  'ciel.atoriye.com': 79,
#  'clocktower.social': 531,
#  'cliff.social': 39,
#  'clj.social': 3219,
#  'cloud-native.social': 11173,
#  'clockwork.monster': 3604,
#  'closednetwork.social': 477,
#  'cloud.zannoni.eu': 19,
#  'cl.ricecream.company': 3723,
#  'cloudkeeper.dev': 143,
#  'cloudycrux.es': 65,
#  'clq.im': 856,
#  'clowntown.app': 7950,
#  'chocot.art': 4124,
#  'clrk.space': 554,
#  'club.darknight-coffee.org': 0,
#  'cloudisland.nz': 247412,
#  'cmdr.social': 6595,
#  ...}

# %%
len(available_local_posts)
# Out:
# 10817

# %%
crawled_data = []
for instance in crawled_counts.keys():
    if instance in top10_crawled_instances:
        favicon_path = save_favicon(instance)
    else:
        favicon_path = None
    crawled_data.append({
        "instance": instance,
        "icon": favicon_path if favicon_path is not None else None,
        "posts_available_local": available_local_posts.get(instance, 0),
        "posts_crawled": crawled_counts.get(instance, 0),
        "posts_crawled_federated": crawled_federated_counts.get(instance, 0),
        "posts_crawled_local": crawled_local_counts.get(instance, 0),
    })

df_crawled = DataFrame(crawled_data)
df_crawled["percentage_crawled_federated_of_crawled"] = \
    df_crawled["posts_crawled_federated"] / df_crawled["posts_crawled"]
df_crawled["percentage_crawled_local_of_crawled"] = \
    df_crawled["posts_crawled_local"] / df_crawled["posts_crawled"]
df_crawled["percentage_crawled_of_crawled"] = \
    df_crawled["percentage_crawled_federated_of_crawled"] + \
        df_crawled["percentage_crawled_local_of_crawled"]  # Sanity check.
assert (df_crawled["percentage_crawled_of_crawled"] == 1).all()
df_crawled.drop(columns=["percentage_crawled_of_crawled"])
df_crawled["percentage_crawled_federated_of_all_crawled_federated"] = \
    df_crawled["posts_crawled_federated"] / \
        df_crawled["posts_crawled_federated"].sum()
df_crawled["percentage_crawled_local_of_all_crawled_local"] = \
    df_crawled["posts_crawled_local"] / \
        df_crawled["posts_crawled_local"].sum()
df_crawled["percentage_crawled_of_all_crawled"] = \
    df_crawled["posts_crawled"] / df_crawled["posts_crawled"].sum()
df_crawled["percentage_available_local_of_all_crawled_available_local"] = \
    df_crawled["posts_available_local"] / \
        df_crawled["posts_available_local"].sum()
df_crawled["percentage_available_local_of_all_discovered_available_local"] = \
    df_crawled["posts_available_local"] / \
        sum(available_local_posts.values())
df_crawled["percentage_crawled_local_of_available_local"] = \
    df_crawled["posts_crawled_local"] / df_crawled["posts_available_local"]
df_crawled.head(n=10).style\
    .format({
        col: "{:,.2%}"
        for col in df_crawled.columns
        if col.startswith("percentage_")
    })
# Out:
# <style type="text/css">
# </style>
# <table id="T_9546d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9546d_level0_col0" class="col_heading level0 col0" >instance</th>
#       <th id="T_9546d_level0_col1" class="col_heading level0 col1" >icon</th>
#       <th id="T_9546d_level0_col2" class="col_heading level0 col2" >posts_available_local</th>
#       <th id="T_9546d_level0_col3" class="col_heading level0 col3" >posts_crawled</th>
#       <th id="T_9546d_level0_col4" class="col_heading level0 col4" >posts_crawled_federated</th>
#       <th id="T_9546d_level0_col5" class="col_heading level0 col5" >posts_crawled_local</th>
#       <th id="T_9546d_level0_col6" class="col_heading level0 col6" >percentage_crawled_federated_of_crawled</th>
#       <th id="T_9546d_level0_col7" class="col_heading level0 col7" >percentage_crawled_local_of_crawled</th>
#       <th id="T_9546d_level0_col8" class="col_heading level0 col8" >percentage_crawled_of_crawled</th>
#       <th id="T_9546d_level0_col9" class="col_heading level0 col9" >percentage_crawled_federated_of_all_crawled_federated</th>
#       <th id="T_9546d_level0_col10" class="col_heading level0 col10" >percentage_crawled_local_of_all_crawled_local</th>
#       <th id="T_9546d_level0_col11" class="col_heading level0 col11" >percentage_crawled_of_all_crawled</th>
#       <th id="T_9546d_level0_col12" class="col_heading level0 col12" >percentage_available_local_of_all_crawled_available_local</th>
#       <th id="T_9546d_level0_col13" class="col_heading level0 col13" >percentage_available_local_of_all_discovered_available_local</th>
#       <th id="T_9546d_level0_col14" class="col_heading level0 col14" >percentage_crawled_local_of_available_local</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9546d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9546d_row0_col0" class="data row0 col0" >mastodon.social</td>
#       <td id="T_9546d_row0_col1" class="data row0 col1" >../data/favicons/favicon-mastodon.social.png</td>
#       <td id="T_9546d_row0_col2" class="data row0 col2" >81205325</td>
#       <td id="T_9546d_row0_col3" class="data row0 col3" >15668157</td>
#       <td id="T_9546d_row0_col4" class="data row0 col4" >12542364</td>
#       <td id="T_9546d_row0_col5" class="data row0 col5" >3125793</td>
#       <td id="T_9546d_row0_col6" class="data row0 col6" >80.05%</td>
#       <td id="T_9546d_row0_col7" class="data row0 col7" >19.95%</td>
#       <td id="T_9546d_row0_col8" class="data row0 col8" >100.00%</td>
#       <td id="T_9546d_row0_col9" class="data row0 col9" >1.73%</td>
#       <td id="T_9546d_row0_col10" class="data row0 col10" >31.34%</td>
#       <td id="T_9546d_row0_col11" class="data row0 col11" >2.14%</td>
#       <td id="T_9546d_row0_col12" class="data row0 col12" >21.05%</td>
#       <td id="T_9546d_row0_col13" class="data row0 col13" >9.86%</td>
#       <td id="T_9546d_row0_col14" class="data row0 col14" >3.85%</td>
#     </tr>
#     <tr>
#       <th id="T_9546d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9546d_row1_col0" class="data row1 col0" >mastodon.online</td>
#       <td id="T_9546d_row1_col1" class="data row1 col1" >../data/favicons/favicon-mastodon.online.png</td>
#       <td id="T_9546d_row1_col2" class="data row1 col2" >7759995</td>
#       <td id="T_9546d_row1_col3" class="data row1 col3" >9857093</td>
#       <td id="T_9546d_row1_col4" class="data row1 col4" >9570010</td>
#       <td id="T_9546d_row1_col5" class="data row1 col5" >287083</td>
#       <td id="T_9546d_row1_col6" class="data row1 col6" >97.09%</td>
#       <td id="T_9546d_row1_col7" class="data row1 col7" >2.91%</td>
#       <td id="T_9546d_row1_col8" class="data row1 col8" >100.00%</td>
#       <td id="T_9546d_row1_col9" class="data row1 col9" >1.32%</td>
#       <td id="T_9546d_row1_col10" class="data row1 col10" >2.88%</td>
#       <td id="T_9546d_row1_col11" class="data row1 col11" >1.34%</td>
#       <td id="T_9546d_row1_col12" class="data row1 col12" >2.01%</td>
#       <td id="T_9546d_row1_col13" class="data row1 col13" >0.94%</td>
#       <td id="T_9546d_row1_col14" class="data row1 col14" >3.70%</td>
#     </tr>
#     <tr>
#       <th id="T_9546d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9546d_row2_col0" class="data row2 col0" >mstdn.social</td>
#       <td id="T_9546d_row2_col1" class="data row2 col1" >../data/favicons/favicon-mstdn.social.png</td>
#       <td id="T_9546d_row2_col2" class="data row2 col2" >14989224</td>
#       <td id="T_9546d_row2_col3" class="data row2 col3" >9638803</td>
#       <td id="T_9546d_row2_col4" class="data row2 col4" >9267685</td>
#       <td id="T_9546d_row2_col5" class="data row2 col5" >371118</td>
#       <td id="T_9546d_row2_col6" class="data row2 col6" >96.15%</td>
#       <td id="T_9546d_row2_col7" class="data row2 col7" >3.85%</td>
#       <td id="T_9546d_row2_col8" class="data row2 col8" >100.00%</td>
#       <td id="T_9546d_row2_col9" class="data row2 col9" >1.28%</td>
#       <td id="T_9546d_row2_col10" class="data row2 col10" >3.72%</td>
#       <td id="T_9546d_row2_col11" class="data row2 col11" >1.31%</td>
#       <td id="T_9546d_row2_col12" class="data row2 col12" >3.89%</td>
#       <td id="T_9546d_row2_col13" class="data row2 col13" >1.82%</td>
#       <td id="T_9546d_row2_col14" class="data row2 col14" >2.48%</td>
#     </tr>
#     <tr>
#       <th id="T_9546d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9546d_row3_col0" class="data row3 col0" >ohai.social</td>
#       <td id="T_9546d_row3_col1" class="data row3 col1" >../data/favicons/favicon-ohai.social.png</td>
#       <td id="T_9546d_row3_col2" class="data row3 col2" >1180837</td>
#       <td id="T_9546d_row3_col3" class="data row3 col3" >8754882</td>
#       <td id="T_9546d_row3_col4" class="data row3 col4" >8735250</td>
#       <td id="T_9546d_row3_col5" class="data row3 col5" >19632</td>
#       <td id="T_9546d_row3_col6" class="data row3 col6" >99.78%</td>
#       <td id="T_9546d_row3_col7" class="data row3 col7" >0.22%</td>
#       <td id="T_9546d_row3_col8" class="data row3 col8" >100.00%</td>
#       <td id="T_9546d_row3_col9" class="data row3 col9" >1.21%</td>
#       <td id="T_9546d_row3_col10" class="data row3 col10" >0.20%</td>
#       <td id="T_9546d_row3_col11" class="data row3 col11" >1.19%</td>
#       <td id="T_9546d_row3_col12" class="data row3 col12" >0.31%</td>
#       <td id="T_9546d_row3_col13" class="data row3 col13" >0.14%</td>
#       <td id="T_9546d_row3_col14" class="data row3 col14" >1.66%</td>
#     </tr>
#     <tr>
#       <th id="T_9546d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9546d_row4_col0" class="data row4 col0" >mas.to</td>
#       <td id="T_9546d_row4_col1" class="data row4 col1" >../data/favicons/favicon-mas.to.png</td>
#       <td id="T_9546d_row4_col2" class="data row4 col2" >7021649</td>
#       <td id="T_9546d_row4_col3" class="data row4 col3" >8208704</td>
#       <td id="T_9546d_row4_col4" class="data row4 col4" >8034084</td>
#       <td id="T_9546d_row4_col5" class="data row4 col5" >174620</td>
#       <td id="T_9546d_row4_col6" class="data row4 col6" >97.87%</td>
#       <td id="T_9546d_row4_col7" class="data row4 col7" >2.13%</td>
#       <td id="T_9546d_row4_col8" class="data row4 col8" >100.00%</td>
#       <td id="T_9546d_row4_col9" class="data row4 col9" >1.11%</td>
#       <td id="T_9546d_row4_col10" class="data row4 col10" >1.75%</td>
#       <td id="T_9546d_row4_col11" class="data row4 col11" >1.12%</td>
#       <td id="T_9546d_row4_col12" class="data row4 col12" >1.82%</td>
#       <td id="T_9546d_row4_col13" class="data row4 col13" >0.85%</td>
#       <td id="T_9546d_row4_col14" class="data row4 col14" >2.49%</td>
#     </tr>
#     <tr>
#       <th id="T_9546d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9546d_row5_col0" class="data row5 col0" >mastodon.world</td>
#       <td id="T_9546d_row5_col1" class="data row5 col1" >../data/favicons/favicon-mastodon.world.png</td>
#       <td id="T_9546d_row5_col2" class="data row5 col2" >4912465</td>
#       <td id="T_9546d_r

# %%
print(r"\begin{tabular}{@{}cl@{\hspace{2em}}rr@{\hspace{1.5em}}rrr@{\hspace{1.5em}}rrrr@{\hspace{2em}}rr@{}}")
print(r"  \toprule")
cols = [
    r"\multicolumn{2}{@{}l}{\textbf{Instance}}",
    r"\multicolumn{9}{c}{\textbf{\iconCrawled~Crawled posts}}",
    r"\multicolumn{2}{c}{\textbf{\iconDiscovered~Available}}",
]
print(r"  " + " & ".join(cols) + r" \\")
print(r"  \cmidrule(r{2em}){3-11}\cmidrule{12-13}")
cols = [
    r"",
    r"",
    r"\multicolumn{1}{c}{\iconLocalFederated~Loc.+fed.}",
    r"\multicolumn{1}{c@{\hspace{1.5em}}}{{\tiny\faIcon{arrow-down}}\iconLocalFederated}",
    r"\multicolumn{1}{c}{\iconFederated~Fed.}",
    r"\multicolumn{1}{c}{{\tiny\faIcon{arrow-down}}\iconFederated}",
    r"\multicolumn{1}{c@{\hspace{1.5em}}}{{\tiny\faIcon{arrow-left}}\iconLocalFederated}",
    r"\multicolumn{1}{c}{\iconLocal~Local}",
    r"\multicolumn{1}{c}{{\tiny\faIcon{arrow-down}}\iconLocal}",
    r"\multicolumn{1}{c}{{\tiny\faIcon{arrow-left}}\iconLocalFederated}",
    r"\multicolumn{1}{c@{\hspace{2em}}}{{\tiny\faIcon{arrow-right}}\iconDiscovered}",
    r"\multicolumn{1}{l}{\iconLocal~Local}",
    r"\multicolumn{1}{c}{{\tiny\faIcon{arrow-down}}\iconCrawled}",
]
print(r"  " + " & ".join(cols) + r" \\")
print(r"  \midrule")
df_crawled_head = df_crawled.sort_values("posts_crawled", ascending=False).head(n=10)
for _, row in df_crawled_head.iterrows():
    favicon_path = save_favicon(row["instance"], quiet=True)
    cols = [
        r"\favicon{" + (row["instance"] if favicon_path is not None else "mastodon.social") + r"}",
        r"\instance{" + row["instance"] + r"}",
        f"{row['posts_crawled']:,d}",
        f"{row['percentage_crawled_of_all_crawled']:,.0%}".replace("%", r"\%"),
        f"{row['posts_crawled_federated']:,d}",
        f"{row['percentage_crawled_federated_of_all_crawled_federated']:,.0%}".replace("%", r"\%"),
        f"{row['percentage_crawled_federated_of_crawled']:,.0%}".replace("%", r"\%"),
        f"{row['posts_crawled_local']:,d}",
        f"{row['percentage_crawled_local_of_all_crawled_local']:,.0%}".replace("%", r"\%"),
        f"{row['percentage_crawled_local_of_crawled']:,.0%}".replace("%", r"\%"),
        f"{row['percentage_crawled_local_of_available_local']:,.0%}".replace("%", r"\%"),
        f"{row['posts_available_local']:,d}",
        f"{row['percentage_available_local_of_all_crawled_available_local']:,.0%}".replace("%", r"\%"),
    ]
    print(r"  " + " & ".join(cols) + r" \\")
df_crawled_tail = df_crawled[~df_crawled.index.isin(df_crawled_head.index)]
cols = [
    r"\iconMore",
    f"{len(df_crawled_tail):,d}" + r" others",
    f"{df_crawled_tail['posts_crawled'].sum():,d}",
    f"{df_crawled_tail['percentage_crawled_of_all_crawled'].sum():,.0%}".replace("%", r"\%"),
    f"{df_crawled_tail['posts_crawled_federated'].sum():,d}",
    f"{df_crawled_tail['percentage_crawled_federated_of_all_crawled_federated'].sum():,.0%}".replace("%", r"\%"),
    f"{(df_crawled_tail['posts_crawled_federated'].sum() / df_crawled['posts_crawled'].sum()):,.0%}".replace("%", r"\%"),
    f"{df_crawled_tail['posts_crawled_local'].sum():,d}",
    f"{df_crawled_tail['percentage_crawled_local_of_all_crawled_local'].sum():,.0%}".replace("%", r"\%"),
    f"{(df_crawled_tail['posts_crawled_local'].sum() / df_crawled['posts_crawled'].sum()):,.0%}".replace("%", r"\%"),
    f"{(df_crawled_tail['posts_crawled_local'].sum() / df_crawled['posts_available_local'].sum()):,.0%}".replace("%", r"\%"),
    f"{df_crawled_tail['posts_available_local'].sum():,d}",
    f"{(df_crawled_tail['percentage_available_local_of_all_crawled_available_local'].sum()):,.0%}".replace("%", r"\%"),
]
cols = [r"\secondary{" + col + r"}" for col in cols]
print(r"  " + " & ".join(cols) + r" \\")
print(r"  \midrule")
cols = [
    r"\iconCrawled",
    f"{len(df_crawled):,d}" + r" crawled",
    f"{df_crawled['posts_crawled'].sum():,d}",
    f"{df_crawled['percentage_crawled_of_all_crawled'].sum():,.0%}".replace("%", r"\%"),
    f"{df_crawled['posts_crawled_federated'].sum():,d}",
    f"{df_crawled['percentage_crawled_federated_of_all_crawled_federated'].sum():,.0%}".replace("%", r"\%"),
    f"{(df_crawled_tail['posts_crawled_federated'].sum() / df_crawled['posts_crawled'].sum()):,.0%}".replace("%", r"\%"),
    f"{df_crawled['posts_crawled_local'].sum():,d}",
    f"{df_crawled['percentage_crawled_local_of_all_crawled_local'].sum():,.0%}".replace("%", r"\%"),
    f"{(df_crawled_tail['posts_crawled_local'].sum() / df_crawled['posts_crawled'].sum()):,.0%}".replace("%", r"\%"),
    f"{(df_crawled['posts_crawled_local'].sum() / df_crawled['posts_available_local'].sum()):,.0%}".replace("%", r"\%"),
    f"{df_crawled['posts_available_local'].sum():,d}",
    f"{(df_crawled['percentage_available_local_of_all_crawled_available_local'].sum()):,.0%}".replace("%", r"\%"),
]
print(r"  " + " & ".join(cols) + r" \\")
cols = [
    r"\iconDiscovered",
    r"11,822 discovered",
    f"---",
    f"---",
    f"---",
    f"---",
    f"---",
    f"---",
    f"---",
    f"---",
    f"---",
    f"{sum(available_local_posts.values()):,d}",
    f"{(sum(available_local_posts.values()) / df_crawled['posts_available_local'].sum()):,.0%}".replace("%", r"\%"),
]
cols = [r"\secondary{" + col + r"}" for col in cols]
print(r"  " + " & ".join(cols) + r" \\")
print(r"  \bottomrule")
print(r"\end{tabular}")
# Out:
# \begin{tabular}{@{}cl@{\hspace{2em}}rr@{\hspace{1.5em}}rrr@{\hspace{1.5em}}rrrr@{\hspace{2em}}rr@{}}
#   \toprule
#   \multicolumn{2}{@{}l}{\textbf{Instance}} & \multicolumn{9}{c}{\textbf{\iconCrawled~Crawled posts}} & \multicolumn{2}{c}{\textbf{\iconDiscovered~Available}} \\
#   \cmidrule(r{2em}){3-11}\cmidrule{12-13}
#    &  & \multicolumn{1}{c}{\iconLocalFederated~Loc.+fed.} & \multicolumn{1}{c@{\hspace{1.5em}}}{{\tiny\faIcon{arrow-down}}\iconLocalFederated} & \multicolumn{1}{c}{\iconFederated~Fed.} & \multicolumn{1}{c}{{\tiny\faIcon{arrow-down}}\iconFederated} & \multicolumn{1}{c@{\hspace{1.5em}}}{{\tiny\faIcon{arrow-left}}\iconLocalFederated} & \multicolumn{1}{c}{\iconLocal~Local} & \multicolumn{1}{c}{{\tiny\faIcon{arrow-down}}\iconLocal} & \multicolumn{1}{c}{{\tiny\faIcon{arrow-left}}\iconLocalFederated} & \multicolumn{1}{c@{\hspace{2em}}}{{\tiny\faIcon{arrow-right}}\iconDiscovered} & \multicolumn{1}{l}{\iconLocal~Local} & \multicolumn{1}{c}{{\tiny\faIcon{arrow-down}}\iconCrawled} \\
#   \midrule
#   \favicon{mastodon.social} & \instance{mastodon.social} & 15,668,157 & 2\% & 12,542,364 & 2\% & 80\% & 3,125,793 & 31\% & 20\% & 4\% & 81,205,325 & 21\% \\
#   \favicon{mastodon.online} & \instance{mastodon.online} & 9,857,093 & 1\% & 9,570,010 & 1\% & 97\% & 287,083 & 3\% & 3\% & 4\% & 7,759,995 & 2\% \\
#   \favicon{mstdn.social} & \instance{mstdn.social} & 9,638,803 & 1\% & 9,267,685 & 1\% & 96\% & 371,118 & 4\% & 4\% & 2\% & 14,989,224 & 4\% \\
#   \favicon{ohai.social} & \instance{ohai.social} & 8,754,882 & 1\% & 8,735,250 & 1\% & 100\% & 19,632 & 0\% & 0\% & 2\% & 1,180,837 & 0\% \\
#   \favicon{mas.to} & \instance{mas.to} & 8,208,704 & 1\% & 8,034,084 & 1\% & 98\% & 174,620 & 2\% & 2\% & 2\% & 7,021,649 & 2\% \\
#   \favicon{mastodon.world} & \instance{mastodon.world} & 8,149,459 & 1\% & 7,968,251 & 1\% & 98\% & 181,208 & 2\% & 2\% & 4\% & 4,912,465 & 1\% \\
#   \favicon{universeodon.com} & \instance{universeodon.com} & 7,489,453 & 1\% & 7,399,674 & 1\% & 99\% & 89,779 & 1\% & 1\% & 3\% & 2,852,641 & 1\% \\
#   \favicon{social.vivaldi.net} & \instance{social.vivaldi.net} & 7,194,763 & 1\% & 7,055,731 & 1\% & 98\% & 139,032 & 1\% & 2\% & 8\% & 1,709,786 & 0\% \\
#   \favicon{techhub.social} & \instance{techhub.social} & 7,121,898 & 1\% & 7,047,603 & 1\% & 99\% & 74,295 & 1\% & 1\% & 5\% & 1,404,970 & 0\% \\
#   \favicon{toot.community} & \instance{toot.community} & 6,660,323 & 1\% & 6,630,708 & 1\% & 100\% & 29,615 & 0\% & 0\% & 2\% & 1,303,738 & 0\% \\
#   \secondary{\iconMore} & \secondary{1,005 others} & \secondary{644,299,273} & \secondary{88\%} & \secondary{638,818,385} & \secondary{88\%} & \secondary{87\%} & \secondary{5,480,888} & \secondary{55\%} & \secondary{1\%} & \secondary{1\%} & \secondary{261,449,365} & \secondary{68\%} \\
#   \midrule
#   \iconCrawled & 1,015 crawled & 733,042,808 & 100\% & 723,069,745 & 100\% & 87\% & 9,973,063 & 100\% & 1\% & 3\% & 385,789,995 & 100\% \\
#   \secondary{\iconDiscovered} & \secondary{11,822 discovered} & \secondary{---} & \secondary{---} & \secondary{---} & \secondary{---} & \secondary{---} & \secondary{---} & \secondary{---} & \secondary{---} & \secondary{---} & \secondary{823,560,767} & \secondary{213\%} \\
#   \bottomrule
# \end{tabular}

# %%
source_instances_count_search: Search = base_search.params(size=0)
source_instances_count_search.aggs\
    .metric(
        "instances", 
        Cardinality(field="instance.keyword")
    )
source_instances_count = source_instances_count_search.execute()\
    .aggs.instances.value
source_instances_count
# Out:
# 16655

# %%
source_unique_post_counts_search: Search = base_search.params(size=0)
source_unique_post_counts_search.aggs\
    .bucket(
        "instances",
        PerTerms(field="instance.keyword", size=source_instances_count)
    )\
    .metric(
        "uris", 
        Cardinality(field="uri.keyword")
    )
    
source_unique_post_counts_buckets = source_unique_post_counts_search.execute().aggs.instances.buckets
source_unique_post_counts = {
    bucket.key: bucket.uris.value
    for bucket in source_unique_post_counts_buckets
}
source_unique_post_counts
# Out:
# {'mastodon.social': 4274826,
#  'mstdn.social': 744583,
#  'press.coop': 217370,
#  'mastodon.online': 474488,
#  'mastodon.world': 319467,
#  'fedibird.com': 605355,
#  'universeodon.com': 179680,
#  'submarin.online': 141630,
#  'infosec.exchange': 193183,
#  'sportsbots.xyz': 667792,
#  'mas.to': 337294,
#  'misskey.io': 1797527,
#  'live-theater.net': 699158,
#  'chaos.social': 254880,
#  'rss-mstdn.studiofreesia.com': 205544,
#  'botsin.space': 223952,
#  'masto.globaleas.org': 309973,
#  'misskey.gg': 65127,
#  'masto.ai': 131717,
#  'mastodonapp.uk': 133624,
#  'hachyderm.io': 168019,
#  'troet.cafe': 258219,
#  'tech.lgbt': 218394,
#  'mastodon.art': 131288,
#  'mstdn.jp': 839146,
#  'pubeurope.com': 67264,
#  'vivaldi.net': 165435,
#  'mstdn.ca': 156046,
#  'mamot.fr': 101052,
#  'sfba.social': 107726,
#  'mastodon.nl': 154164,
#  'channels.im': 156308,
#  'fosstodon.org': 122733,
#  'kolektiva.social': 128107,
#  'beige.party': 117760,
#  'pravda.me': 107177,
#  'newsie.social': 77888,
#  'flipboard.com': 110502,
#  'gratefuldread.masto.host': 30822,
#  'mas.corq.co': 37538,
#  'techhub.social': 107823,
#  'aus.social': 106741,
#  'squeet.me': 27993,
#  'journa.host': 20717,
#  'wandering.shop': 76928,
#  'mastodon.scot': 118544,
#  'norden.social': 136591,
#  'flipboard.social': 22572,
#  'piaille.fr': 145579,
#  'firefish.ranranhome.info': 294414,
#  'misskey-square.net': 427559,
#  'c.im': 88258,
#  'osintua.eu': 28437,
#  'social.tchncs.de': 105226,
#  'mi.nakn.jp': 101992,
#  'airwaves.social': 37496,
#  'm.ai6yr.org': 41787,
#  'm.cmx.im': 122015,
#  'best-friends.chat': 268785,
#  'mindly.social': 67529,
#  'lepoulsdumonde.com': 17375,
#  'mstdn.kemono-friends.info': 124107,
#  'meow.social': 88955,
#  'wxw.moe': 155385,
#  'mastodon.cloud': 70811,
#  'mastodon.hongkongers.net': 87502,
#  'octodon.social': 55567,
#  'pokemon.mastportal.info': 83751,
#  'wetdry.world': 71128,
#  'mastodon.gamedev.place': 64057,
#  'vive.im': 46772,
#  'toot.community': 60409,
#  'schleuss.online': 17004,
#  'ard.social': 5294,
#  'mastodon.ie': 60910,
#  'mastodon.sdf.org': 72037,
#  'zirk.us': 46557,
#  'noc.social': 16849,
#  'nrw.social': 88976,
#  'ohai.social': 50945,
#  'o3o.ca': 89785,
#  'dice.camp': 53642,
#  'todon.eu': 38223,
#  'sportsfeed.me': 26455,
#  'eldritch.cafe': 70805,
#  'social.lansky.name': 7004,
#  'unnerv.jp': 12427,
#  'mastodon.green': 43480,
#  'prismisskey.space': 76896,
#  'g0v.social': 23596,
#  'mastodon-japan.net': 181131,
#  'mastodon.nu': 52522,
#  'darktundra.xyz': 10852,
#  'social.heise.de': 6256,
#  'pawoo.net': 168222,
#  'bots.krohsnest.com': 130866,
#  'mastodon.uno': 66335,
#  'indieweb.social': 23703,
#  'masto.es': 53780,
#  'hackers.town': 28244,
#  'respublicae.eu': 67262,
#  'meta.masto.host': 5236,
#  'writing.exchange': 28588,
#  'fediscience.org': 19859,
#  'mstdn.party': 56060,
#  'xscape.top': 9954,
#  'sueden.social': 39214,
#  'cyberpunk.lol': 11922,
#  'vmst.io': 17041,
#  'planet.moe': 48745,
#  'toot.wales': 32403,
#  'social.coop': 26146,
#  'strangeobject.space': 19560,
#  'social.mikutter.hachune.net': 57426,
#  'mk.absturztau.be': 25083,
#  'hostux.social': 28012,
#  'anonsys.net': 41540,
#  'digitalcourage.social': 36610,
#  'climatejustice.social': 31738,
#  'treehouse.systems': 32394,
#  'jorts.horse': 25803,
#  'plush.city': 22171,
#  'framapiaf.org': 41768,
#  'chaosphere.hostdon.jp': 48243,
#  'bae.st': 126610,
#  'mastodon.nz': 31073,
#  'mastodon.crazynewworld.net': 10566,
#  'toot.cat': 29536,
#  'med-mastodon.com': 24236,
#  'mathstodon.xyz': 25124,
#  'schaumburg.social': 14485,
#  'monads.online': 44496,
#  'rss-parrot.net': 628638,
#  'thecanadian.social': 11858,
#  'derstandard.at': 3481,
#  'labo.wovs.tk': 41135,
#  'urbanists.social': 22179,
#  'mastodont.cat': 24368,
#  'bgme.me': 42922,
#  'mstdn.beer': 41919,
#  'social.lol': 25483,
#  'nowplaying.radiofreefedi.net': 50414,
#  'metalhead.club': 28061,
#  'mstdn.games': 25789,
#  'berserker.town': 6117,
#  'mastodon.ml': 27296,
#  'det.social': 40035,
#  'pixelfed.social': 32017,
#  'photog.social': 32440,
#  'dragonscave.space': 16931,
#  'todon.nl': 15353,
#  'mementomori.social': 14768,
#  'social.cologne': 32562,
#  'misskey.design': 116146,
#  'rockosbasilisk.com': 12803,
#  'dmv.community': 9178,
#  'muenchen.social': 28627,
#  'paquita.masto.host': 39213,
#  'ursal.zone': 31327,
#  'mastodon.au': 22703,
#  'social.1up.ninja': 22343,
#  'mastodon.xyz': 19470,
#  'terere.social': 15681,
#  'k.lapy.link': 30405,
#  'qoto.org': 32472,
#  'ruhr.social': 31725,
#  'famichiki.jp': 17380,
#  'chaosfem.tw': 18921,
#  'queer.party': 25072,
#  'shitposter.club': 49536,
#  'lile.cl': 9187,
#  'phpc.social': 15871,
#  'die-partei.social': 5461,
#  'hessen.social': 32238,
#  'yiff.life': 19488,
#  'alive.bar': 84440,
#  'bitbang.social': 14181,
#  'babka.social': 18869,
#  'toad.social': 33847,
#  'social.espeweb.net': 23033,
#  'disabled.social': 21908,
#  'social.bund.de': 4113,
#  'floss.social': 16122,
#  'socel.net': 23972,
#  'orfodon.org': 12017,
#  'nerdculture.de': 23123,
#  'ioc.exchange': 17114,
#  'twit.social': 15675,
#  'fedi.nano.lgbt': 9441,
#  'berlin.social': 21910,
#  'misskey.noellabo.jp': 40465,
#  'digipres.club': 8838,
#  'catswords.social': 5370,
#  'social.hispabot.freemyip.com': 9837,
#  'transit.alerts.social': 56020,
#  'mastodon.me.uk': 19776,
#  'tenforward.social': 14721,
#  'newspapers.se': 43383,
#  'fnordon.de': 18660,
#  'transfem.social': 22827,
#  'oldbytes.space': 16862,
#  'cloudisland.nz': 13277,
#  'retro.social': 6593,
#  'veganism.social': 16799,
#  'furry.engineer': 24371,
#  'mstdn.business': 4691,
#  'misskey.backspace.fm': 211233,
#  'poa.st': 103829,
#  'me.dm': 16804,
#  'dresden.network': 18421,
#  'mstdn.science': 14816,
#  'xoxo.zone': 10378,
#  'hcommons.social': 8472,
#  'sauropods.win': 12912,
#  'social.beachcom.org': 3549,
#  'bildung.social': 16211,
#  'misskey.takehi.to': 17015,
#  'retro.pizza': 16234,
#  'froggie.gay': 7744,
#  'toot.cafe': 7673,
#  'ubuntu.social': 6912,
#  'gamepad.club': 10301,
#  'zhub.link': 9651,
#  'nijimiss.moe': 276037,
#  'girlcock.club': 24362,
#  'openbiblio.social': 14600,
#  'rivals.space': 14593,
#  'woof.group': 24702,
#  'translunar.academy': 23741,
#  'cyberplace.social': 3554,
#  'lgbtqia.space': 21945,
#  'kiritan.work': 48070,
#  'noauthority.social': 53929,
#  'tooters.org': 12726,
#  'lemmy.world': 57370,
#  'zug.network': 14618,
#  'cryptodon.lol': 21673,
#  'shigusegubu.club': 10771,
#  'ieji.de': 17014,
#  'front-end.social': 6804,
#  'charcha.cc': 45719,
#  'voskey.icalo.net': 190971,
#  'horrorhub.club': 7059,
#  'dvd.chat': 7094,
#  'hello.2heng.xin': 10955,
#  'masto.pt': 17022,
#  'chitter.xyz': 17071,
#  'cupoftea.social': 16474,
#  'hellsite.site': 17038,
#  'literatur.social': 21546,
#  'historians.social': 25675,
#  'mastodon.laurenweinstein.org': 3051,
#  'federated.press': 7187,
#  'sunny.garden': 12010,
#  'social.anoxinon.de': 17318,
#  'nobigtech.es': 9004,
#  'mastodon.la': 18723,
#  'tweesecake.social': 11339,
#  'kind.social': 21318,
#  'jb.md': 4977,
#  'woem.men': 13258,
#  'peoplemaking.games': 10614,
#  'nekomiya.net': 24330,
#  'zeroes.ca': 13662,
#  'genix.ink': 8758,
#  'eigenmagic.net': 6447,
#  'tkz.one': 18310,
#  'lor.sh': 28821,
#  'bolha.us': 7529,
#  'pdx.social': 7745,
#  'freeradical.zone': 19186,
#  'ai.wiki': 14227,
#  'myamisskey.ddo.jp': 18730,
#  'nycity.social': 7257,
#  'merveilles.town': 6309,
#  'fedi.catboy.agency': 10839,
#  'chrispelli.fun': 4566,
#  'milker.cafe': 44660,
#  'fed.sbcloud.cc': 8083,
#  'mastodon.top': 17743,
#  'fairy.id': 3416,
#  'rheinneckar.social': 12312,
#  'vocalodon.net': 70231,
#  'defcon.social': 10405,
#  'mastodontech.de': 16779,
#  'cosocial.ca': 5859,
#  'petrous.vislae.town': 31885,
#  'social.edist.ro': 12749,
#  'abyss.fun': 6059,
#  'bark.lgbt': 20017,
#  'papi.n1l.dev': 14524,
#  'appdot.net': 7224,
#  'swiss.social': 11767,
#  'mastodon.tinyfox.dev': 4445,
#  'scholar.social': 6244,
#  'eightpoint.app': 19803,
#  'mastodon.bida.im': 11911,
#  'eupolicy.social': 6868,
#  'spore.social': 8239,
#  'social.linux.pizza': 24136,
#  'misskey.art': 109452,
#  'mstdn.maud.io': 22333,
#  'kafeneio.social': 10831,
#  'warpday.net': 17031,
#  'toot.io': 6049,
#  'misskey.cloud': 21157,
#  'heads.social': 10180,
#  'ravenation.club': 11859,
#  'educhat.social': 6557,
#  'mendeddrum.org': 8257,
#  'm.tkngh.jp': 19438,
#  'tilde.zone': 11089,
#  'partyparrot.social': 3354,
#  'tldr.nettime.org': 17382,
#  'ecoevo.social': 11847,
#  'sociale.network': 29765,
#  'mastodon.trueten.de': 2800,
#  'blob.cat': 10848,
#  'mastodon-uk.net': 7522,
#  'sciences.re': 8782,
#  'imastodon.net': 110954,
#  'astrodon.social': 6297,
#  'ruby.social': 12427,
#  'mastodon.radio': 13782,
#  'icosahedron.website': 8809,
#  'toot.aquilenet.fr': 8575,
#  'corteximplant.com': 11804,
#  'neurodifferent.me': 14409,
#  'glammr.us': 8227,
#  'wakoka.com': 33343,
#  'newsbots.californialocal.com': 14184,
#  'toot.garden': 5013,
#  'toot.blue': 26130,
#  '9kb.me': 13192,
#  'goblin.camp': 10816,
#  'pounced-on.me': 10137,
#  'tooting.ch': 10318,
#  'mastodon.london': 6613,
#  'social.kyiv.dcomm.net.ua': 24815,
#  'mastoxiv.page': 57025,
#  'ojousama-tea.party': 9748,
#  'noagendasocial.com': 36389,
#  'minds.com': 174727,
#  'mastodon.motcha.tech': 4947,
#  'mstdn.nere9.help': 9636,
#  'kinkyelephant.com': 9040,
#  'mstdn.sirmaple.ca': 4993,
#  'mstdn.poyo.me': 8335,
#  'me.ns.ci': 16164,
#  'friendicarg.nsupdate.info': 43045,
#  'mast.shitpostbot.com': 3010,
#  'woem.space': 11816,
#  'mstd.seungjin.net': 14498,
#  'federate.social': 5344,
#  'shakedown.social': 12865,
#  'uri.life': 13979,
#  'acg.mn': 3055,
#  'catcatnya.com': 15147,
#  'sakurajima.moe': 8690,
#  'mastodonbooks.net': 3995,
#  'misskey.niri.la': 126374,
#  'flipping.rocks': 7014,
#  'officiell-info.se': 6510,
#  'social.yl.ms': 3380,
#  'hci.social': 5297,
#  '101010.pl': 12924,
#  '0w0.is': 10098,
#  'macaw.social': 3855,
#  'toot.lv': 9420,
#  'scicomm.xyz': 4123,
#  'awscommunity.social': 5734,
#  'mastodon.neilzone.co.uk': 4915,
#  'weirder.earth': 15323,
#  'mastodonczech.cz': 11936,
#  'freiburg.social': 15817,
#  'researchbuzz.masto.host': 2871,
#  'esq.social': 4942,
#  'mastodontti.fi': 10156,
#  'mastodonsweden.se': 15187,
#  'pouet.chapril.org': 20658,
#  'crooklyn.social': 1722,
#  'unfufadoo.net': 3967,
#  'gruene.social': 6656,
#  'union.place': 14308,
#  'toot.majorshouse.com': 2083,
#  'mastodon-swiss.org': 8377,
#  'layer8.space': 4909,
#  'misskey.secinet.jp': 3860,
#  'transmom.love': 2982,
#  'glaceon.social': 10541,
#  'post.lurk.org': 4544,
#  'yandere.cc': 16260,
#  'kmy.blue': 31565,
#  'newsmast.social': 34333,
#  'mi.mashiro.site': 13347,
#  'mastodon.de': 9328,
#  'm.eula.dev': 2546,
#  'mastodon.org.uk': 6072,
#  'masto.bike': 11209,
#  'mstdn.y-zu.org': 9638,
#  'brotka.st': 4071,
#  'meteo.social': 2038,
#  'romancelandia.club': 7595,
#  'raggedfeathers.com': 2150,
#  'lumberjacks.social': 1379,
#  'nofan.xyz': 19290,
#  'rollenspiel.social': 10731,
#  'misskey.04.si': 22245,
#  'lizards.live': 3132,
#  'mastodon.murkworks.net': 5998,
#  'jforo.com': 65482,
#  'sigmoid.social': 5941,
#  'worldkey.io': 5062,
#  'urusai.social': 8722,
#  'mastodon.mikmak.cc': 14185,
#  'wrestling.social': 5221,
#  'sciences.social': 5727,
#  'friend.camp': 3332,
#  'toot.lgbt': 9719,
#  'infosec.town': 4743,
#  'mastodon.adtension.com': 1637,
#  'mk.nyaa.place': 3837,
#  'mastodon.thenewoil.org': 990,
#  'mastodon.bot': 9774,
#  'pawb.fun': 8499,
#  'hugs.lgbt': 22009,
#  'niklas.social': 5714,
#  'cybre.club': 40200,
#  'lain.com': 1832,
#  'mastodon.energy': 5426,
#  'dju.social': 5122,
#  'friendica.myportal.social': 6909,
#  'pol.social': 12015,
#  'geeknews.chat': 966,
#  'moth.social': 4001,
#  'anticapitalist.party': 6114,
#  'gaygeek.social': 7252,
#  'mstdn.mx': 7611,
#  'mast.eu.org': 3554,
#  'pony.social': 3355,
#  'plasmatrap.com': 11927,
#  'dan.mastohon.com': 1699,
#  'libranet.de': 6553,
#  'nitecrew.rip': 5673,
#  'functional.cafe': 5703,
#  'musician.social': 4118,
#  'bonn.social': 8433,
#  'bne.social': 4959,
#  'fandom.ink': 6996,
#  'theblower.au': 8274,
#  'waha.work': 12104,
#  'stella.place': 11413,
#  'alaskan.social': 4010,
#  'livellosegreto.it': 11383,
#  'loforo.com': 12376,
#  'outerheaven.club': 7635,
#  'mstdn.io': 8588,
#  'wien.rocks': 6235,
#  'mspsocial.net': 5674,
#  'mastdn.social': 4542,
#  'portside.social': 9182,
#  'blahaj.social': 2553,
#  'systemli.social': 2418,
#  'lingo.lol': 4567,
#  'misskey.noeling.com': 11233,
#  'novelskey.tarbin.net': 143421,
#  'propulse.club': 6133,
#  'raru.re': 6415,
#  'shelter.moe': 19831,
#  'm.mxin.moe': 39333,
#  'venera.social': 6586,
#  'beach.city': 4381,
#  'pug.ninja': 3659,
#  'moresci.sale': 7600,
#  'dair-community.social': 2513,
#  'thicc.horse': 9368,
#  'some.henkkalaukka.fi': 4924,
#  'autistics.life': 5035,
#  'spookygirl.boo': 4975,
#  'shrike.club': 10452,
#  'furactive.us': 6787,
#  'bsd.network': 7401,
#  'thepit.social': 6706,
#  'pbs.idv.tw': 20594,
#  'social.afront.org': 2700,
#  'cutie.city': 10143,
#  'neovibe.app': 2509,
#  'topspicy.social': 9098,
#  'blorbo.social': 10524,
#  'mediapart.social': 1115,
#  'genart.social': 3106,
#  'oekakiskey.com': 65371,
#  'lunar.place': 3533,
#  'beepboop.one': 2451,
#  'drdr.club': 6316,
#  'fedi.astrid.tech': 2113,
#  'forall.social': 2527,
#  'social.saarland': 6739,
#  'mastodon.design': 5673,
#  'mastodon.coffee': 6171,
#  'mast.moe': 4927,
#  'stranger.social': 8170,
#  'seal.cafe': 4971,
#  'fedia.social': 2500,
#  'sysadmin.run': 7176,
#  'syzito.xyz': 4163,
#  'eliitin-some.fi': 5387,
#  'p1.a9z.dev': 8673,
#  'mstdn.asterism.xyz': 6379,
#  'toot.site': 7040,
#  'xarxa.cloud': 9552,
#  'precure.ml': 6837,
#  'convo.casa': 2791,
#  'blacktwitter.io': 2742,
#  'poliverso.org': 5945,
#  'vis.social': 3611,
#  'mi.kitsunebi-ya.com': 5218,
#  'social.wildeboer.net': 1163,
#  'machikadon.online': 5447,
#  'pulpunte-chinpun.xyz': 6285,
#  'firefish.city': 1844,
#  'eepy.moe': 8862,
#  'mastodon.sandwich.net': 2849,
#  'neuromatch.social': 5397,
#  'timetheft.social': 6362,
#  'nekoplanet.xyz': 12061,
#  'types.pl': 5275,
#  'nfld.me': 1737,
#  'honi.club': 9059,
#  'cheeseburger.social': 1698,
#  'tuiter.rocks': 8646,
#  'pixelfed.de': 6197,
#  'emacs.ch': 6881,
#  'go5.dev': 9356,
#  'baraag.net': 42976,
#  'yoshida2015.net': 4284,
#  'nafo.uk': 3192,
#  'allthingstech.social': 5619,
#  'studio8502.ca': 3629,
#  'social.beaware.live': 6196,
#  'mastodon.rip': 2530,
#  'mkkey.net': 72829,
#  'msky.h3z.jp': 5908,
#  'mellified.men': 2351,
#  'discuss.systems': 4174,
#  'blimps.xyz': 7326,
#  'snabelen.no': 11437,
#  'androiddev.social': 3880,
#  'suyasuya.love': 5187,
#  'social.vivaldi.net': 138717,
#  'sns.onjann.club': 1240,
#  'river.group.lt': 4078,
#  'tacobelllabs.net': 9313,
#  'diaspodon.fr': 6909,
#  'tiggi.es': 7894,
#  'mastodon.uy': 5730,
#  'songbird.cloud': 14292,
#  'frikiverse.zone': 7178,
#  'msky.haruyjsn.net': 7853,
#  'mastodon.ar.al': 1924,
#  'iosdev.space': 5094,
#  'ottawa.place': 8499,
#  'kinky.business': 10975,
#  'mapstodon.space': 3328,
#  'mefi.social': 6897,
#  'chirp.enworld.org': 2832,
#  'mastodon-belgium.be': 9706,
#  'lgbt.io': 7497,
#  'loma.ml': 4538,
#  'mastodon.com.br': 3403,
#  'linuxrocks.online': 4305,
#  'pointless.chat': 5758,
#  'mstdn.fujii-yuji.net': 2186,
#  'abraham.su': 1857,
#  'wobbl.xyz': 10223,
#  'mona.do': 14481,
#  'en.osm.town': 6700,
#  'netzkae.se': 4352,
#  'pullopen.xyz': 5405,
#  'libretooth.gr': 7535,
#  'social.fedinet.de': 1689,
#  'legal.social': 4924,
#  'catgirl.center': 6743,
#  'triangletoot.party': 3851,
#  'kirche.social': 10583,
#  'wank.social': 11588,
#  'v.st': 6727,
#  'amefur.asia': 6326,
#  'indieauthors.social': 3440,
#  'oc.todon.fr': 5833,
#  '3zi.ru': 21151,
#  'toot.bike': 4889,
#  'hispagatos.space': 2417,
#  'mysportgallery.com': 2101,
#  'typo.social': 4749,
#  'col.social': 6707,
#  'puntarella.party': 4608,
#  'godforsaken.website': 5165,
#  'mastodon.ozioso.online': 3257,
#  'dosgame.club': 4517,
#  'laserdisc.party': 6367,
#  'rubber.social': 7070,
#  '1234.as': 7538,
#  'uff.rip': 4277,
#  'wisskomm.social': 2136,
#  'nicecrew.digital': 30828,
#  'thefolklore.cafe': 1991,
#  'jawns.club': 4907,
#  'borg.social': 1904,
#  'archaeo.social': 2992,
#  'america.social': 3593,
#  'glasgow.social': 4555,
#  'mastodon.in.th': 6525,
#  'macstories.net': 1063,
#  'stoat.zone': 3652,
#  'mastodon.tucsonsentinel.com': 574,
#  'wikis.world': 1880,
#  'greenjobs.social': 2592,
#  'mozilla.social': 5429,
#  'queer.cool': 3892,
#  'cathode.church': 6288,
#  'possum.city': 7406,
#  'lemmy.ml': 33467,
#  'social.dev-wiki.de': 9701,
#  'anarres.family': 6342,
#  'gsg.live': 1553,
#  'macrofurs.social': 7203,
#  'lea.pet': 5915,
#  'sushi.ski': 47426,
#  'idw-online.social': 1932,
#  'dobbs.town': 5035,
#  '4bear.com': 8201,
#  'libera.site': 10494,
#  'mastodon.wurzelmann.at': 2771,
#  'stellaria.network': 5711,
#  'skinheads.social': 6410,
#  'splatoon3.ink': 1311,
#  'social.dytrych.cloud': 15954,
#  'boteden.com': 9326,
#  'social.sdf.org': 5060,
#  'mastodon.arch-linux.cz': 5791,
#  'blahaj.zone': 8705,
#  'gamedev.lgbt': 3436,
#  'mastodon.cr': 4363,
#  'ahlroos.me': 2610,
#  'im-in.space': 3250,
#  'social.ridetrans.it': 3149,
#  'mastobotti.eu': 11821,
#  'hoto.moe': 6126,
#  'weatherishappening.network': 3107,
#  'kitsunes.club': 6539,
#  'm.aqr.af': 6155,
#  'freeatlantis.com': 20750,
#  'ol2ol.com': 25207,
#  'vt.social': 5735,
#  'bots.fedi.cr': 19842,
#  'darmstadt.social': 6443,
#  'nightly.fedibird.com': 4074,
#  'dragon.style': 5482,
#  'mastodon.education': 5619,
#  '802.3ether.net': 14530,
#  'onlybsds.com': 1982,
#  'm.lonet.org': 1997,
#  'handon.club': 21506,
#  'labyrinth.zone': 10035,
#  'elekk.xyz': 5869,
#  'misskey.m544.net': 9234,
#  'makai.chaotic.ninja': 2592,
#  'mstdn.plusminus.io': 11916,
#  'bertshouse.social': 3823,
#  'wxcloud.social': 2141,
#  'social.network.europa.eu': 481,
#  'cryptodon.chat': 2417,
#  'mastodon.berlin': 2267,
#  'vtdon.com': 6117,
#  'cubhub.social': 9427,
#  'bots.defencegeeks.net': 10661,
#  'mastodon.eus': 10787,
#  'team.matechan.com': 8285,
#  'girlc.at': 4212,
#  'astolfo.social': 2270,
#  'mastodon.gal': 6778,
#  'grimgreenfo.rest': 4515,
#  'mastodon.zunda.ninja': 2547,
#  'social.tulsa.ok.us': 1174,
#  'oldfriends.live': 1131,
#  'graz.social': 3631,
#  'geekdom.social': 8219,
#  'io.mwl.io': 1630,
#  'mk.f72u.net': 2785,
#  'mk.shrimpia.network': 29282,
#  'mastodon.zaclys.com': 6244,
#  'beekeeping.ninja': 5147,
#  'obak-key.com': 5247,
#  'social.br-linux.org': 1584,
#  'varishangout.net': 16929,
#  'gulp.cafe': 6658,
#  'epicure.social': 5023,
#  'hoosier.social': 5220,
#  'brands.town': 4045,
#  'mstdn.home.neso.tech': 4221,
#  'kpop.social': 3743,
#  'momo.mame.moe': 2096,
#  'mstdn.chrisalemany.ca': 3150,
#  'solarpunk.moe': 4901,
#  'social.mondoweiss.net': 438,
#  'graphics.social': 3279,
#  'weird.autos': 3475,
#  'pagan.plus': 4516,
#  'mi.7mi.site': 2185,
#  'micro.blog': 18284,
#  'mostr.pub': 36744,
#  'mastodon.archive.org': 1722,
#  'k18plus.social': 1994,
#  'gensokyo.social': 3973,
#  'musicians.today': 5607,
#  'nomanssky.social': 1992,
#  'graeber.social': 3908,
#  'philly.vs-the.world': 3328,
#  'mstdn.digital': 2325,
#  'slime.global': 1691,
#  'discordian.social': 19494,
#  'mastodon.nzoss.nz': 1942,
#  's.pfm.cx': 1290,
#  'a2mi.social': 14816,
#  'bookwor.ms': 7259,
#  'exile.social': 1575,
#  'moppels.bar': 9543,
#  'zdf.social': 376,
#  'queer.af': 4097,
#  'mstdn.fr': 3417,
#  'm.einverne.info': 2514,
#  'transfur.social': 2143,
#  'social.prepedia.org': 10219,
#  'ourislandgeorgia.net': 858,
#  'misskey.systems': 50120,
#  'cultofshiv.wtf': 3988,
#  'assemblag.es': 2335,
#  'one.darnell.one': 983,
#  'mastodon.cisti.org': 16288,
#  'oslo.town': 4402,
#  'thingy.social': 1229,
#  'mastodon.cardina1.red': 3419,
#  'mastodon.lawprofs.org': 1956,
#  'oransns.com': 4700,
#  'furries.club': 4075,
#  'qaf.men': 1023,
#  'federation.network': 4360,
#  'texasobserver.social': 937,
#  'social.bau-ha.us': 1974,
#  'sunbeam.city': 4745,
#  'witten.social': 2090,
#  'bawü.social': 1871,
#  'apobangpo.space': 3143,
#  'posts.rat.pictures': 586,
#  'liberdon.com': 7212,
#  'birdon.social': 3396,
#  'iqhina.org': 4567,
#  'better.boston': 3325,
#  'fedihum.org': 2879,
#  'mastodon.iriseden.eu': 3293,
#  'friendsofdesoto.social': 3315,
#  'mstdn.plus': 8469,
#  'misskey.nokotaro.com': 1988,
#  'techpolicy.social': 1708,
#  'bewegung.social': 1876,
#  'girldick.gay': 4524,
#  'ni.hil.ist': 6641,
#  'h-i.social': 1707,
#  'partyon.xyz': 505,
#  'pnw.zone': 4042,
#  'labyrinth.social': 1646,
#  'tapbots.social': 1545,
#  'is-a.wyvern.rip': 2088,
#  'misskey.sweshelo.jp': 4032,
#  'social.skynetcloud.site': 7638,
#  'genomic.social': 5298,
#  'cyberfurz.social': 3094,
#  'koliosky.com': 11471,
#  'den.raccoon.quest': 9717,
#  'slashine.onl': 7002,
#  'ramen-fsm.eu.org': 6225,
#  'corneill.es': 3512,
#  'ilyamikcoder.com': 2341,
#  'masto.deoan.org': 1105,
#  'haunted.computer': 2590,
#  'otadon.com': 16176,
#  'mastorol.es': 10213,
#  'hear-me.social': 2379,
#  'climatejustice.rocks': 5338,
#  'bbq.snoot.com': 2494,
#  'canada.masto.host': 3472,
#  'silicon.moe': 4846,
#  'sometimes.social': 989,
#  'darkfriend.social': 1938,
#  'twoot.site': 4673,
#  'mastodon.gougere.fr': 1734,
#  'fedinerds.social': 3195,
#  'einestages.friediversum.de': 5388,
#  'arc-en-ciel.hostdon.ne.jp': 2884,
#  'social.macg.co': 923,
#  'msk.ilnk.info': 5427,
#  'brain.d.on-t.work': 7301,
#  'kurry.social': 3701,
#  'handmade.social': 2355,
#  'social.datalabour.com': 2010,
#  'queer.group': 5143,
#  'helvede.net': 8489,
#  'social.growyourown.services': 468,
#  'buicha.social': 50918,
#  'mxtthxw.art': 1582,
#  'glitterkitten.co.uk': 1223,
#  'gorone.xyz': 6152,
#  'surfin.dog': 2358,
#  'selfhosted.cafe': 1531,
#  'tutoteket.no': 3139,
#  'atomicpoet.org': 506,
#  'flower.afn.social': 46569,
#  'under-bank.blue': 2997,
#  'barca.dix.asia': 5478,
#  'beamship.mpaq.org': 2625,
#  'moth.zone': 4583,
#  'equestria.social': 4479,
#  'mao.mastodonhub.com': 6783,
#  'tootr.co': 2442,
#  'miss.mouse.services': 1600,
#  'maniakey.com': 27171,
#  'misskey.dev': 19268,
#  '9ineverse.com': 23084,
#  'snug.moe': 6547,
#  'mastodon.hach.re': 706,
#  'lethallava.land': 6481,
#  'seafoam.space': 5522,
#  'douchi.space': 3763,
#  'funami.tech': 1535,
#  'bolha.one': 3232,
#  'mastoot.fr': 2504,
#  'mst.muiiio.com': 1918,
#  'fribygda.no': 4854,
#  'progressivecafe.social': 4488,
#  'lubar.me': 2420,
#  'simonwillison.net': 576,
#  'jiskey.dev': 4526,
#  'bookstodon.com': 4335,
#  'exquisite.social': 1111,
#  'palewi.re': 3364,
#  'pertsch.social': 1516,
#  'misskey.pm': 2876,
#  'garuru.f5.si': 4218,
#  'elbmatsch.de': 1380,
#  'i.peacht.art': 4712,
#  'gs.leftic.club': 2605,
#  'fedi.xerz.one': 1605,
#  'social.chiefgyk3d.com': 670,
#  'masto.donte.com.br': 3427,
#  'akko.wtf': 7728,
#  'tyrol.social': 3201,
#  'kollegin.eu': 69255,
#  'h4.io': 4794,
#  'libera.tokyo': 2715,
#  'mastodon.sg': 3928,
#  'theverge.space': 4590,
#  'feedsin.space': 46054,
#  'spinster.xyz': 18051,
#  'kemonodon.club': 16957,
#  'lounge.town': 2940,
#  'minohdon.jp': 3190,
#  'mobilite-mobiliteit.brussels': 1167,
#  'spacey.space': 5466,
#  'isfeeling.social': 1321,
#  'oceanplayground.social': 2039,
#  'idlethumbs.social': 1275,
#  'bsd.cafe': 3300,
#  'a.gup.pe': 48539,
#  'zeppelin.flights': 1298,
#  'hourly.photo': 11327,
#  'h-net.social': 1710,
#  'mk.u0conveni.club': 2230,
#  'social.cu2d.com': 15354,
#  'crimew.gay': 5740,
#  'tiny.tilde.website': 2322,
#  'meow.woem.cat': 2038,
#  'misskey.gamelore.fun': 44947,
#  'boitam.eu': 6553,
#  'circumstances.run': 2066,
#  'posts.dumb.stuff.donaberger.xyz': 687,
#  'mastodon.quebec': 3073,
#  'shonk.phite.ro': 6207,
#  'mastodon.terabyte-computing.com': 640,
#  'buttersc.one': 6357,
#  'fedi.absturztau.be': 6306,
#  'ludosphere.fr': 4854,
#  'matrix.rocks': 2134,
#  'shonk.social': 3691,
#  'don.linxx.net': 4056,
#  'pkm.social': 3011,
#  'no-pony.farm': 1697,
#  'code4lib.social': 1072,
#  'mastodon.heavymusic.rocks': 730,
#  'esoteric.party': 1677,
#  'metreee.com': 2661,
#  'birds.town': 3328,
#  'catodon.social': 2509,
#  'climatejustice.global': 1164,
#  'dads.cool': 2378,
#  'jasette.facil.services': 3217,
#  'mastodonters.nl': 1330,
#  'skeptics.social': 2539,
#  'utter.online': 2384,
#  'spoilertv.social': 1233,
#  'ani.work': 2874,
#  'tokyoto.cyou': 3211,
#  'lsbt.me': 3560,
#  'aethy.com': 27032,
#  'c18.masto.host': 955,
#  'wandzeitung.xyz': 2704,
#  'piipitin.fi': 2294,
#  'swiss-talk.net': 2101,
#  'social.boom.army': 1661,
#  'sharma.io': 1589,
#  'fouroclockfarms.club': 1483,
#  'expressional.social': 9388,
#  'lustigetiernamenbubble.de': 5388,
#  'shahu.ski': 4113,
#  'ap.ketsuben.red': 9018,
#  'toot.mantyke.icu': 1501,
#  'social.politicaconciencia.org': 3736,
#  'mastodon.thirring.org': 5440,
#  'chinwag.org': 2692,
#  'momo.dosuto.net': 2509,
#  'm.otter.homes': 11970,
#  'werd.social': 359,
#  'gardenstate.social': 1850,
#  'mastodon.acm.org': 2363,
#  'cr8r.gg': 1962,
#  'syringa.social': 1766,
#  'm.universetoday.com': 503,
#  'witter.cz': 2436,
#  'progressives.social': 1460,
#  'kitty.haus': 2675,
#  'bungle.online': 2967,
#  'podcasts.social': 2104,
#  'fediverse.one': 363,
#  'rssfeed.media': 3920,
#  'social.rebellion.global': 2367,
#  'nileane.fr': 1051,
#  'federatedfandom.net': 4644,
#  'sciencemastodon.com': 1736,
#  'redwombat.social': 1166,
#  'rebelbase.site': 5395,
#  'm.tkw.fm': 3108,
#  'metrobus.masto.host': 2323,
#  'aoir.social': 1131,
#  'social.masto.land': 409,
#  'peculiar.florist': 2131,
#  'econtwitter.net': 1622,
#  'misskey.seitendan.com': 3071,
#  'phire.place': 1863,
#  'earthshaker.fygod.life': 1693,
#  'foresdon.jp': 9883,
#  'edi.social': 187,
#  'tooot.im': 3432,
#  'poag.one': 827,
#  'procial.tchncs.de': 5771,
#  'daepi.so': 3276,
#  'mastodon.monoceros.co.za': 1862,
#  'astronomy.social': 351,
#  'bikeshed.vibber.net': 407,
#  'tooter.social': 2634,
#  'mast.yourautisticlife.com': 1154,
#  'simian.rodeo': 868,
#  'deadinsi.de': 5198,
#  'toot.yukimochi.jp': 1297,
#  'd-64.social': 2774,
#  'miau.jeder.pl': 3472,
#  'fandom.garden': 3106,
#  'nuwasocial.com': 5676,
#  'glauca.space': 1150,
#  'turtleisland.social': 2462,
#  'kitty.social': 3078,
#  'wargamers.social': 2321,
#  'particle.lol': 1685,
#  'social.anacreonte.eu': 8355,
#  'madost.one': 3303,
#  'bagarrosphere.fr': 1706,
#  'sakurajima.social': 5461,
#  'social.spejset.org': 4045,
#  'press.anyaforger.art': 18574,
#  'arvr.social': 1311,
#  'bikeshed.party': 1271,
#  'misskey.omhnc.net': 4732,
#  'mastodon.clinicians-exchange.org': 781,
#  'social.overheid.nl': 1039,
#  'zoner.work': 2378,
#  'systerserver.town': 841,
#  'akademienl.social': 932,
#  'raccoon.place': 1482,
#  'mountains.social': 2322,
#  'fire.asta.lgbt': 1758,
#  'meemu.org': 2655,
#  ...}

# %%
top_source_instances: list[str] = [
    instance
    for instance, _ in sorted(
        source_unique_post_counts.items(), 
        key=lambda b: b[1],
        reverse=True,
    )[:10]
]
top_source_instances
# Out:
# ['mastodon.social',
#  'misskey.io',
#  'mstdn.jp',
#  'mstdn.social',
#  'live-theater.net',
#  'sportsbots.xyz',
#  'rss-parrot.net',
#  'fedibird.com',
#  'mastodon.online',
#  'misskey-square.net']

# %%
source_base_search = base_search\
    .filter(Terms(instance__keyword=top_source_instances))
source_base_search.count()
# Out:
# 204094157

# %%
source_post_stats_search: Search = source_base_search.params(size=0)
source_post_stats_agg_instance = source_post_stats_search.aggs\
    .bucket(
        "instances",
        PerTerms(field="instance.keyword", size=len(top_source_instances))
    )
source_post_stats_agg_instance\
    .metric(
        "uris", 
        Cardinality(field="uri.keyword")
    )
source_post_stats_agg_instance\
    .bucket(
        "is_local",
        PerTerms(field="is_local")
    )\
    .metric(
        "uris", 
        Cardinality(field="uri.keyword")
    )
source_post_stats_agg_instance\
    .bucket(
        "is_local",
        PerTerms(field="is_local")
    )\
    .metric(
        "uris", 
        Cardinality(field="uri.keyword")
    )
    
source_post_stats = source_post_stats_search.execute().aggs
source_post_stats
# Out:
# {'instances': {'doc_count_error_upper_bound': 0, 'sum_other_...}

# %%
source_post_stats.to_dict()
# Out:
# {'instances': {'doc_count_error_upper_bound': 0,
#   'sum_other_doc_count': 0,
#   'buckets': [{'key': 'mastodon.social',
#     'doc_count': 117824474,
#     'uris': {'value': 4274826},
#     'is_local': {'doc_count_error_upper_bound': 0,
#      'sum_other_doc_count': 0,
#      'buckets': [{'key': 0,
#        'key_as_string': 'false',
#        'doc_count': 114698681,
#        'uris': {'value': 4272571}},
#       {'key': 1,
#        'key_as_string': 'true',
#        'doc_count': 3125793,
#        'uris': {'value': 3136413}}]}},
#    {'key': 'mstdn.social',
#     'doc_count': 23639564,
#     'uris': {'value': 744583},
#     'is_local': {'doc_count_error_upper_bound': 0,
#      'sum_other_doc_count': 0,
#      'buckets': [{'key': 0,
#        'key_as_string': 'false',
#        'doc_count': 23268446,
#        'uris': {'value': 744583}},
#       {'key': 1,
#        'key_as_string': 'true',
#        'doc_count': 371118,
#        'uris': {'value': 368703}}]}},
#    {'key': 'mastodon.online',
#     'doc_count': 19115512,
#     'uris': {'value': 474488},
#     'is_local': {'doc_count_error_upper_bound': 0,
#      'sum_other_doc_count': 0,
#      'buckets': [{'key': 0,
#        'key_as_string': 'false',
#        'doc_count': 18828429,
#        'uris': {'value': 474488}},
#       {'key': 1,
#        'key_as_string': 'true',
#        'doc_count': 287083,
#        'uris': {'value': 288110}}]}},
#    {'key': 'fedibird.com',
#     'doc_count': 11063638,
#     'uris': {'value': 605355},
#     'is_local': {'doc_count_error_upper_bound': 0,
#      'sum_other_doc_count': 0,
#      'buckets': [{'key': 0,
#        'key_as_string': 'false',
#        'doc_count': 10804287,
#        'uris': {'value': 600555}},
#       {'key': 1,
#        'key_as_string': 'true',
#        'doc_count': 259351,
#        'uris': {'value': 261232}}]}},
#    {'key': 'sportsbots.xyz',
#     'doc_count': 8839332,
#     'uris': {'value': 667792},
#     'is_local': {'doc_count_error_upper_bound': 0,
#      'sum_other_doc_count': 0,
#      'buckets': [{'key': 0,
#        'key_as_string': 'false',
#        'doc_count': 8839332,
#        'uris': {'value': 667792}}]}},
#    {'key': 'misskey.io',
#     'doc_count': 8312148,
#     'uris': {'value': 1797527},
#     'is_local': {'doc_count_error_upper_bound': 0,
#      'sum_other_doc_count': 0,
#      'buckets': [{'key': 0,
#        'key_as_string': 'false',
#        'doc_count': 8312148,
#        'uris': {'value': 1797527}}]}},
#    {'key': 'live-theater.net',
#     'doc_count': 8218396,
#     'uris': {'value': 699158},
#     'is_local': {'doc_count_error_upper_bound': 0,
#      'sum_other_doc_count': 0,
#      'buckets': [{'key': 0,
#        'key_as_string': 'false',
#        'doc_count': 8218396,
#        'uris': {'value': 699158}}]}},
#    {'key': 'mstdn.jp',
#     'doc_count': 4142186,
#     'uris': {'value': 839146},
#     'is_local': {'doc_count_error_upper_bound': 0,
#      'sum_other_doc_count': 0,
#      'buckets': [{'key': 0,
#        'key_as_string': 'false',
#        'doc_count': 4142186,
#        'uris': {'value': 839146}}]}},
#    {'key': 'misskey-square.net',
#     'doc_count': 2237804,
#     'uris': {'value': 427559},
#     'is_local': {'doc_count_error_upper_bound': 0,
#      'sum_other_doc_count': 0,
#      'buckets': [{'key': 0,
#        'key_as_string': 'false',
#        'doc_count': 2237804,
#        'uris': {'value': 427559}}]}},
#    {'key': 'rss-parrot.net',
#     'doc_count': 701103,
#     'uris': {'value': 628638},
#     'is_local': {'doc_count_error_upper_bound': 0,
#      'sum_other_doc_count': 0,
#      'buckets': [{'key': 0,
#        'key_as_string': 'false',
#        'doc_count': 701103,
#        'uris': {'value': 628638}}]}}]}}

# %%
## Determine the top 10 instances.
index = [
    bucket
    for bucket, _ in zip(sorted(crawled_federated_counts), range(NUM_EXPLICIT_INSTANCES))
]
for i in range(NUM_EXPLICIT_INSTANCES):
    index.append(buckets[i]["key"])
instances = index.copy()
## Count "others".
others_label = str(len(buckets) - NUM_EXPLICIT_INSTANCES) + " others"
## Count "all crawled".
crawled_label = str(len(buckets)) + " crawled"

index.extend((others_label, crawled_label))
index

# %%
# Evaluate data
fed_posts = {}
fed_users = {}
local_posts = {}
local_users = {}
## Federated and local search results look the same, so we can do the same stuff twice.
for search_result, posts, users in (
    (fed_data_result, fed_posts, fed_users),
    (local_data_result, local_posts, local_users)
):
    ## list → dict
    data_dict = {
        entry["key"]: {
            "doc_count": entry["doc_count"],
            "users": entry["users"]["value"]
        }
        for entry in search_result.aggs["instances"]["buckets"]
    }
    ## top 10
    for instance in instances:
        posts[instance] = data_dict[instance]["doc_count"]
        users[instance] = data_dict[instance]["users"]
        del data_dict[instance]
    ## Others / all crawled
    posts[others_label] = sum(v["doc_count"] for v in data_dict.values())
    posts[crawled_label] = sum(posts.values())
## Local users ~(top 10)
local_users[others_label] = sum(v["users"]["value"] for v in local_data_result.aggs["instances"]["buckets"])
## Local users all crawled
local_users[crawled_label] = sum(local_users.values())

# %%
fed_posts

# %%
fed_users

# %%
local_posts

# %%
local_users

# %%
# Federated users and deduplicated posts is not as easy – we need additional searches for these.
## Prepare Query for instances: ~(top 10)
not_top10_query = Q()
for instance in instances:
    not_top10_query = not_top10_query & ~Q("term", crawled_from_instance=instance)

# %%
# Federated posts values contain duplicates. We want to display one of these values later,
# but the main DataFrame should contain deduplicated values as they are way more meaningful.
fed_crawled_dup_posts = fed_posts[crawled_label]
fed_crawled_dup_posts

# %%
# Federated deduplicated posts, ~(top 10).
dedup_posts_other_search = Index(INDEX).search().params(size=0).query(date_query).query("bool", filter=not_top10_query)
dedup_posts_other_search.aggs.bucket("posts", "cardinality", field="uri.keyword")
dedup_posts_other_result = dedup_posts_other_search.execute()

fed_posts[others_label] = dedup_posts_other_result.aggs["posts"]["value"]
fed_posts[others_label]

# %%
# Federated deduplicated posts, all crawled.
dedup_posts_crawled_search = Index(INDEX).search().params(size=0).query(date_query)
dedup_posts_crawled_search.aggs.bucket("posts", "cardinality", field="uri.keyword")
dedup_posts_crawled_result = dedup_posts_crawled_search.execute()

fed_posts[crawled_label] = dedup_posts_crawled_result.aggs["posts"]["value"]
fed_posts[crawled_label]

# %%
## Federated, ~(top 10)
others_fed_users_search = Index(INDEX).search().params(size=0).query(date_query).query("bool", filter=not_top10_query)
others_fed_users_search.aggs.bucket("users", "cardinality", field="account.handle.keyword")
others_fed_users_result = others_fed_users_search.execute()

fed_users[others_label] = others_fed_users_result.aggs["users"]["value"]
fed_users[others_label]

# %%
## Federated, all crawled
all_fed_users_search = Index(INDEX).search().params(size=0).query(date_query)
all_fed_users_search.aggs.bucket("users", "cardinality", field="account.handle.keyword")
all_fed_users_result = all_fed_users_search.execute()

fed_users[crawled_label] = all_fed_users_result.aggs["users"]["value"]
fed_users[crawled_label]

# %%
# "Available" data: the entire Mastodon network (that we know of).
## Get all instances we ever crawled.
crawled_instances = set()
with INSTANCES_PATH.open("r") as f:
    for line in f:
        crawled_instances.add(line[:-1])
with REMOVED_INSTANCES_PATH.open("r") as f:
    for instance in loads(f.readline()):
        crawled_instances.add(instance)
## File to dict
mastodon_data = {}
with open(INSTANCE_DATA_PATH, "r") as file:
    for line in file:
        line_dict = loads(line)
        # No nodeinfo means server unreachable or other software.
        if (line_dict["nodeinfo"]):
            # We need either (nodeinfo & activity) or (nodeinfo & software==mastodon)
            if (not line_dict["activity"]):
                if (not line_dict["nodeinfo"]["software"]
                    or not line_dict["nodeinfo"]["software"]["name"] == "mastodon"
                ):
                    continue
            # We only use nodeinfo though.
            mastodon_data[line_dict["instance"]] = line_dict["nodeinfo"]

all_label = str(len(mastodon_data)) + " discovered"
index.append(all_label)

# %%
avail_local_posts = {
    others_label: 0
}
avail_local_users = {
    others_label: 0
}
## top 10
for instance in instances:
    avail_local_posts[instance] = mastodon_data[instance]["usage"]["localPosts"]
    avail_local_users[instance] = mastodon_data[instance]["usage"]["users"]["total"]
    crawled_instances.remove(instance)
## Others (crawled, but not top 10)
for instance in crawled_instances:
    # Some instances might not be present in more recent fediverse data which was obtained later.
    if (instance in mastodon_data):
        avail_local_posts[others_label] += mastodon_data[instance]["usage"]["localPosts"]
        avail_local_users[others_label] += mastodon_data[instance]["usage"]["users"]["total"]
## All crawled
avail_local_posts[crawled_label] = sum(avail_local_posts.values())
avail_local_users[crawled_label] = sum(avail_local_users.values())
## All
avail_local_posts[all_label] = sum(v["usage"]["localPosts"] for v in mastodon_data.values())
avail_local_users[all_label] = sum(v["usage"]["users"]["total"] for v in mastodon_data.values())

# %%
# Append NA, otherwise it will be NaN and the whole column will be converted to float.
for dict in (fed_posts, fed_users, local_posts, local_users):
    dict[all_label] = NA

df = DataFrame(
    {
        ("Crawled", "Posts (fed.)"): fed_posts,
        ("Crawled", "Users (fed.)"): fed_users,
        ("Crawled", "Posts (loc.)"): local_posts,
        ("Crawled", "Users (loc.)"): local_users,
        ("Available", "Posts (loc.)"): avail_local_posts,
        ("Available", "Users (loc.)"): avail_local_users
    },
    index=index
)
df.index.name = "Instance"
df

# %%
# Calculate ratio of crawled posts and users
local_posts_ratio = df.loc[:, ("Crawled", "Posts (loc.)")] /  df.loc[:, ("Available", "Posts (loc.)")]
local_users_ratio = df.loc[:, ("Crawled", "Users (loc.)")] /  df.loc[:, ("Available", "Users (loc.)")]

fed_posts_ratio = {
    all_label: fed_posts[crawled_label] / avail_local_posts[all_label]
}
fed_users_ratio = {
    all_label: fed_users[crawled_label] / avail_local_users[all_label]
}

df_ratios = DataFrame(
    {
        ("Crawled ratio", "Posts (fed.)"): fed_posts_ratio,
        ("Crawled ratio", "Users (fed.)"): fed_users_ratio,
        ("Crawled ratio", "Posts (loc.)"): local_posts_ratio,
        ("Crawled ratio", "Users (loc.)"): local_users_ratio
    },
    index=index
).fillna(NA, axis=1)
df_ratios.index.name = "Instance"

# %%
print("Posts crawled total:", fed_crawled_dup_posts)
print("Of which are duplicates:", fed_crawled_dup_posts - fed_posts[crawled_label])
print("Ratio of original posts:", fed_posts[crawled_label] / fed_crawled_dup_posts)

df

# %% [markdown]
# The above values are deduplicated, which means no single value contains any duplicates. If you take multiple values from one of the *(fed.)* columns though, there will definitely be an intersection.
#
# The values in the *Available* columns above are from a set time. This means, that the ratios below are inexact and, depending on your chosen timeframe, more or less off.

# %%
df_ratios
